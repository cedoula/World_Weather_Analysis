# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests
from datetime import datetime

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 748

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime("%Y-%m-%d %H:%M:%S")
        city_name = city_weather["name"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date, 
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | xining
# Processing Record 2 of the Set 1 | vaini
# Processing Record 3 of the Set 1 | cape town
# Processing Record 4 of the Set 1 | east london
# Processing Record 5 of the Set 1 | hualmay
# Processing Record 6 of the Set 1 | khingansk
# Processing Record 7 of the Set 1 | grindavik
# Processing Record 8 of the Set 1 | mitu
# Processing Record 9 of the Set 1 | matagami
# Processing Record 10 of the Set 1 | olga
# Processing Record 11 of the Set 1 | banyo
# Processing Record 12 of the Set 1 | new norfolk
# Processing Record 13 of the Set 1 | yellowknife
# Processing Record 14 of the Set 1 | hasaki
# Processing Record 15 of the Set 1 | carnarvon
# Processing Record 16 of the Set 1 | jamestown
# Processing Record 17 of the Set 1 | cabo san lucas
# Processing Record 18 of the Set 1 | padang
# Processing Record 19 of the Set 1 | thompson
# Processing Record 20 of the Set 1 | albany
# Processing Record 21 of the Set 1 | bredasdorp
# Processing Record 22 of the Set 1 | san rafael
# Processing Record 23 of the Set 1 | ponta do sol
# Processing Record 24 of the Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 25 of the Set 1 | san carlos de bariloche
# Processing Record 26 of the Set 1 | victoria
# Processing Record 27 of the Set 1 | ust-nera
# Processing Record 28 of the Set 1 | pevek
# Processing Record 29 of the Set 1 | constitucion
# Processing Record 30 of the Set 1 | ilulissat
# Processing Record 31 of the Set 1 | chicama
# Processing Record 32 of the Set 1 | atambua
# Processing Record 33 of the Set 1 | busselton
# Processing Record 34 of the Set 1 | namatanai
# Processing Record 35 of the Set 1 | dikson
# Processing Record 36 of the Set 1 | bereda
# Processing Record 37 of the Set 1 | torbay
# Processing Record 38 of the Set 1 | wajir
# Processing Record 39 of the Set 1 | nikolskoye
# Processing Record 40 of the Set 1 | imeni poliny osipenko
# Processing Record 41 of the Set 1 | deloraine
# Processing Record 42 of the Set 1 | iqaluit
# Processing Record 43 of the Set 1 | todos santos
# Processing Record 44 of the Set 1 | statesboro
# Processing Record 45 of the Set 1 | bethel
# Processing Record 46 of the Set 1 | tungkang
# City not found. Skipping...
# Processing Record 47 of the Set 1 | tasiilaq
# Processing Record 48 of the Set 1 | bara
# Processing Record 49 of the Set 1 | attawapiskat
# Processing Record 50 of the Set 1 | jalu
# Processing Record 1 of the Set 2 | chokurdakh
# Processing Record 2 of the Set 2 | ngunguru
# Processing Record 3 of the Set 2 | puerto ayora
# Processing Record 4 of the Set 2 | dolbeau
# Processing Record 5 of the Set 2 | qaqortoq
# Processing Record 6 of the Set 2 | wexford
# Processing Record 7 of the Set 2 | provideniya
# Processing Record 8 of the Set 2 | punta arenas
# Processing Record 9 of the Set 2 | mentok
# Processing Record 10 of the Set 2 | visnes
# Processing Record 11 of the Set 2 | clyde river
# Processing Record 12 of the Set 2 | barrow
# Processing Record 13 of the Set 2 | beroroha
# Processing Record 14 of the Set 2 | gamba
# Processing Record 15 of the Set 2 | mbanza-ngungu
# Processing Record 16 of the Set 2 | ushuaia
# Processing Record 17 of the Set 2 | ostrovnoy
# Processing Record 18 of the Set 2 | mount isa
# Processing Record 19 of the Set 2 | haines junction
# Processing Record 20 of the Set 2 | beloha
# Processing Record 21 of the Set 2 | zarate
# Processing Record 22 of the Set 2 | salalah
# Processing Record 23 of the Set 2 | pavlivka
# Processing Record 24 of the Set 2 | saint george
# Processing Record 25 of the Set 2 | nargana
# Processing Record 26 of the Set 2 | rikitea
# Processing Record 27 of the Set 2 | mayo
# Processing Record 28 of the Set 2 | mar del plata
# Processing Record 29 of the Set 2 | antalaha
# Processing Record 30 of the Set 2 | hobart
# Processing Record 31 of the Set 2 | taburi
# City not found. Skipping...
# Processing Record 32 of the Set 2 | la romana
# Processing Record 33 of the Set 2 | tsihombe
# Processing Record 34 of the Set 2 | hay river
# Processing Record 35 of the Set 2 | atuona
# Processing Record 36 of the Set 2 | mataura
# Processing Record 37 of the Set 2 | chara
# Processing Record 38 of the Set 2 | kendari
# Processing Record 39 of the Set 2 | qaanaaq
# Processing Record 40 of the Set 2 | rio bueno
# Processing Record 41 of the Set 2 | kuche
# Processing Record 42 of the Set 2 | kodiak
# Processing Record 43 of the Set 2 | sitka
# Processing Record 44 of the Set 2 | avarua
# Processing Record 45 of the Set 2 | samusu
# City not found. Skipping...
# Processing Record 46 of the Set 2 | somerset east
# Processing Record 47 of the Set 2 | kyabram
# Processing Record 48 of the Set 2 | geraldton
# Processing Record 49 of the Set 2 | fortuna
# Processing Record 50 of the Set 2 | hithadhoo
# Processing Record 1 of the Set 3 | fethiye
# Processing Record 2 of the Set 3 | gravdal
# Processing Record 3 of the Set 3 | canalete
# Processing Record 4 of the Set 3 | kaitangata
# Processing Record 5 of the Set 3 | portland
# Processing Record 6 of the Set 3 | tuktoyaktuk
# Processing Record 7 of the Set 3 | kavieng
# Processing Record 8 of the Set 3 | korla
# Processing Record 9 of the Set 3 | belushya guba
# Processing Record 10 of the Set 3 | amderma
# Processing Record 11 of the Set 3 | turukhansk
# Processing Record 12 of the Set 3 | bonavista
# Processing Record 13 of the Set 3 | wajima
# Processing Record 14 of the Set 3 | najran
# Processing Record 15 of the Set 3 | kapaa
# Processing Record 16 of the Set 3 | sri aman
# Processing Record 17 of the Set 3 | swift current
# Processing Record 18 of the Set 3 | gawler
# Processing Record 19 of the Set 3 | chuy
# Processing Record 20 of the Set 3 | mirnyy
# Processing Record 21 of the Set 3 | vila
# Processing Record 22 of the Set 3 | anadyr
# Processing Record 23 of the Set 3 | naryan-mar
# Processing Record 24 of the Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 25 of the Set 3 | bluff
# Processing Record 26 of the Set 3 | dien bien
# City not found. Skipping...
# Processing Record 27 of the Set 3 | butaritari
# Processing Record 28 of the Set 3 | hermanus
# Processing Record 29 of the Set 3 | riberalta
# Processing Record 30 of the Set 3 | turbat
# Processing Record 31 of the Set 3 | georgetown
# Processing Record 32 of the Set 3 | tiksi
# Processing Record 33 of the Set 3 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 34 of the Set 3 | zangakatun
# Processing Record 35 of the Set 3 | vero beach
# Processing Record 36 of the Set 3 | tucuman
# Processing Record 37 of the Set 3 | manavalakurichi
# Processing Record 38 of the Set 3 | esmeraldas
# Processing Record 39 of the Set 3 | nemuro
# Processing Record 40 of the Set 3 | demba
# Processing Record 41 of the Set 3 | faya
# Processing Record 42 of the Set 3 | chapais
# Processing Record 43 of the Set 3 | mahebourg
# Processing Record 44 of the Set 3 | dobris
# Processing Record 45 of the Set 3 | fomboni
# Processing Record 46 of the Set 3 | north platte
# Processing Record 47 of the Set 3 | labuhan
# Processing Record 48 of the Set 3 | hofn
# Processing Record 49 of the Set 3 | sambava
# Processing Record 50 of the Set 3 | nome
# Processing Record 1 of the Set 4 | souillac
# Processing Record 2 of the Set 4 | hilo
# Processing Record 3 of the Set 4 | saskylakh
# Processing Record 4 of the Set 4 | faanui
# Processing Record 5 of the Set 4 | coihueco
# Processing Record 6 of the Set 4 | upernavik
# Processing Record 7 of the Set 4 | paamiut
# Processing Record 8 of the Set 4 | bathsheba
# Processing Record 9 of the Set 4 | altay
# Processing Record 10 of the Set 4 | bantva
# Processing Record 11 of the Set 4 | evensk
# Processing Record 12 of the Set 4 | havre-saint-pierre
# Processing Record 13 of the Set 4 | ketchikan
# Processing Record 14 of the Set 4 | marsh harbour
# Processing Record 15 of the Set 4 | kirakira
# Processing Record 16 of the Set 4 | nyurba
# Processing Record 17 of the Set 4 | tuatapere
# Processing Record 18 of the Set 4 | ancud
# Processing Record 19 of the Set 4 | port alfred
# Processing Record 20 of the Set 4 | berlevag
# Processing Record 21 of the Set 4 | nanortalik
# Processing Record 22 of the Set 4 | embonas
# Processing Record 23 of the Set 4 | taolanaro
# Processing Record 24 of the Set 4 | kununurra
# Processing Record 25 of the Set 4 | odessa
# Processing Record 26 of the Set 4 | mbulu
# Processing Record 27 of the Set 4 | arlit
# Processing Record 28 of the Set 4 | lebu
# Processing Record 29 of the Set 4 | uruguaiana
# Processing Record 30 of the Set 4 | pitimbu
# Processing Record 31 of the Set 4 | dingle
# Processing Record 32 of the Set 4 | pringsewu
# Processing Record 33 of the Set 4 | port elizabeth
# Processing Record 34 of the Set 4 | mount gambier
# Processing Record 35 of the Set 4 | marcala
# Processing Record 36 of the Set 4 | nguiu
# Processing Record 37 of the Set 4 | meulaboh
# Processing Record 38 of the Set 4 | mariakani
# Processing Record 39 of the Set 4 | touros
# Processing Record 40 of the Set 4 | port hawkesbury
# Processing Record 41 of the Set 4 | omaruru
# Processing Record 42 of the Set 4 | acapulco
# Processing Record 43 of the Set 4 | tarko-sale
# Processing Record 44 of the Set 4 | kruisfontein
# Processing Record 45 of the Set 4 | dali
# Processing Record 46 of the Set 4 | castro
# Processing Record 47 of the Set 4 | san ramon
# Processing Record 48 of the Set 4 | ulaangom
# Processing Record 49 of the Set 4 | pavilosta
# Processing Record 50 of the Set 4 | saleaula
# City not found. Skipping...
# Processing Record 1 of the Set 5 | port augusta
# Processing Record 2 of the Set 5 | kitui
# Processing Record 3 of the Set 5 | pacific grove
# Processing Record 4 of the Set 5 | luderitz
# Processing Record 5 of the Set 5 | boguchany
# Processing Record 6 of the Set 5 | barra do garcas
# Processing Record 7 of the Set 5 | talnakh
# Processing Record 8 of the Set 5 | ojinaga
# Processing Record 9 of the Set 5 | khagaria
# Processing Record 10 of the Set 5 | richards bay
# Processing Record 11 of the Set 5 | illoqqortoormiut
# Processing Record 12 of the Set 5 | nizhneyansk
# Processing Record 13 of the Set 5 | samarai
# Processing Record 14 of the Set 5 | mizque
# Processing Record 15 of the Set 5 | hirara
# Processing Record 16 of the Set 5 | sao joao da barra
# Processing Record 17 of the Set 5 | kushmurun
# Processing Record 18 of the Set 5 | vilyuysk
# Processing Record 19 of the Set 5 | maniitsoq
# Processing Record 20 of the Set 5 | ribeira grande
# Processing Record 21 of the Set 5 | luanda
# Processing Record 22 of the Set 5 | zapolyarnyy
# Processing Record 23 of the Set 5 | parrita
# Processing Record 24 of the Set 5 | mount darwin
# Processing Record 25 of the Set 5 | aykhal
# Processing Record 26 of the Set 5 | teya
# Processing Record 27 of the Set 5 | makat
# Processing Record 28 of the Set 5 | isangel
# Processing Record 29 of the Set 5 | shimonoseki
# Processing Record 30 of the Set 5 | husavik
# Processing Record 31 of the Set 5 | anar darreh
# City not found. Skipping...
# Processing Record 32 of the Set 5 | aketi
# Processing Record 33 of the Set 5 | varnavino
# Processing Record 34 of the Set 5 | tome
# Processing Record 35 of the Set 5 | auki
# Processing Record 36 of the Set 5 | foam lake
# Processing Record 37 of the Set 5 | arraial do cabo
# Processing Record 38 of the Set 5 | deputatskiy
# Processing Record 39 of the Set 5 | lorengau
# Processing Record 40 of the Set 5 | chute-aux-outardes
# Processing Record 41 of the Set 5 | pinega
# Processing Record 42 of the Set 5 | varkaus
# Processing Record 43 of the Set 5 | erenhot
# Processing Record 44 of the Set 5 | gangotri
# Processing Record 45 of the Set 5 | aizpute
# Processing Record 46 of the Set 5 | khatanga
# Processing Record 47 of the Set 5 | beira
# Processing Record 48 of the Set 5 | prince rupert
# Processing Record 49 of the Set 5 | girne
# Processing Record 50 of the Set 5 | bengkulu
# Processing Record 1 of the Set 6 | waipawa
# Processing Record 2 of the Set 6 | ovsyanka
# Processing Record 3 of the Set 6 | barawe
# Processing Record 4 of the Set 6 | olinda
# Processing Record 5 of the Set 6 | bargal
# Processing Record 6 of the Set 6 | esperance
# Processing Record 7 of the Set 6 | berezovyy
# Processing Record 8 of the Set 6 | wau
# Processing Record 9 of the Set 6 | mayumba
# Processing Record 10 of the Set 6 | ucluelet
# Processing Record 11 of the Set 6 | vestmannaeyjar
# Processing Record 12 of the Set 6 | kutiyana
# Processing Record 13 of the Set 6 | codrington
# Processing Record 14 of the Set 6 | mildura
# Processing Record 15 of the Set 6 | tiznit
# Processing Record 16 of the Set 6 | grand river south east
# Processing Record 17 of the Set 6 | thohoyandou
# Processing Record 18 of the Set 6 | kupino
# Processing Record 19 of the Set 6 | chimore
# Processing Record 20 of the Set 6 | skalistyy
# Processing Record 21 of the Set 6 | takoradi
# Processing Record 22 of the Set 6 | flinders
# Processing Record 23 of the Set 6 | airai
# Processing Record 24 of the Set 6 | naze
# Processing Record 25 of the Set 6 | trincomalee
# Processing Record 26 of the Set 6 | ilo
# Processing Record 27 of the Set 6 | aklavik
# Processing Record 28 of the Set 6 | bambous virieux
# Processing Record 29 of the Set 6 | saint-philippe
# Processing Record 30 of the Set 6 | vila velha
# Processing Record 31 of the Set 6 | keshan
# Processing Record 32 of the Set 6 | cherskiy
# Processing Record 33 of the Set 6 | ahipara
# Processing Record 34 of the Set 6 | mogadishu
# Processing Record 35 of the Set 6 | mehamn
# Processing Record 36 of the Set 6 | vardo
# Processing Record 37 of the Set 6 | cravo norte
# Processing Record 38 of the Set 6 | svetlogorsk
# Processing Record 39 of the Set 6 | filadelfia
# Processing Record 40 of the Set 6 | berdigestyakh
# Processing Record 41 of the Set 6 | sao filipe
# Processing Record 42 of the Set 6 | cidreira
# Processing Record 43 of the Set 6 | saldanha
# Processing Record 44 of the Set 6 | high level
# Processing Record 45 of the Set 6 | baicheng
# Processing Record 46 of the Set 6 | alofi
# Processing Record 47 of the Set 6 | saint-pierre
# Processing Record 48 of the Set 6 | rockhampton
# Processing Record 49 of the Set 6 | ituni
# City not found. Skipping...
# Processing Record 50 of the Set 6 | whitehorse
# Processing Record 1 of the Set 7 | buala
# Processing Record 2 of the Set 7 | shingu
# Processing Record 3 of the Set 7 | narsaq
# Processing Record 4 of the Set 7 | birao
# Processing Record 5 of the Set 7 | pisco
# Processing Record 6 of the Set 7 | gueret
# Processing Record 7 of the Set 7 | port blair
# Processing Record 8 of the Set 7 | yar-sale
# Processing Record 9 of the Set 7 | heilbad heiligenstadt
# Processing Record 10 of the Set 7 | kieta
# Processing Record 11 of the Set 7 | diapaga
# Processing Record 12 of the Set 7 | shobara
# Processing Record 13 of the Set 7 | severo-yeniseyskiy
# Processing Record 14 of the Set 7 | broome
# Processing Record 15 of the Set 7 | lata
# Processing Record 16 of the Set 7 | pierre
# Processing Record 17 of the Set 7 | maragogi
# Processing Record 18 of the Set 7 | itamaraca
# Processing Record 19 of the Set 7 | namibe
# Processing Record 20 of the Set 7 | lagoa
# Processing Record 21 of the Set 7 | belaya gora
# Processing Record 22 of the Set 7 | monastyrshchina
# Processing Record 23 of the Set 7 | champerico
# Processing Record 24 of the Set 7 | kahului
# Processing Record 25 of the Set 7 | uwayl
# Processing Record 26 of the Set 7 | riyadh
# Processing Record 27 of the Set 7 | roma
# Processing Record 28 of the Set 7 | chaman
# Processing Record 29 of the Set 7 | ust-kuyga
# Processing Record 30 of the Set 7 | nokaneng
# Processing Record 31 of the Set 7 | houma
# Processing Record 32 of the Set 7 | rio cuarto
# Processing Record 33 of the Set 7 | palabuhanratu
# Processing Record 34 of the Set 7 | novoagansk
# Processing Record 35 of the Set 7 | batagay
# Processing Record 36 of the Set 7 | nueva concepcion
# Processing Record 37 of the Set 7 | sentyabrskiy
# Processing Record 38 of the Set 7 | cockburn town
# Processing Record 39 of the Set 7 | tura
# Processing Record 40 of the Set 7 | severo-kurilsk
# Processing Record 41 of the Set 7 | zlobin
# Processing Record 42 of the Set 7 | lerwick
# Processing Record 43 of the Set 7 | sidi ali
# Processing Record 44 of the Set 7 | salisbury
# Processing Record 45 of the Set 7 | manokwari
# Processing Record 46 of the Set 7 | taphan hin
# Processing Record 47 of the Set 7 | constitucion
# Processing Record 48 of the Set 7 | ginir
# Processing Record 49 of the Set 7 | aksu
# Processing Record 50 of the Set 7 | nanchang
# Processing Record 1 of the Set 8 | perth
# Processing Record 2 of the Set 8 | westport
# Processing Record 3 of the Set 8 | nicoya
# Processing Record 4 of the Set 8 | umm lajj
# Processing Record 5 of the Set 8 | arman
# Processing Record 6 of the Set 8 | rodrigues alves
# Processing Record 7 of the Set 8 | nelson bay
# Processing Record 8 of the Set 8 | mys shmidta
# Processing Record 9 of the Set 8 | poindimie
# Processing Record 10 of the Set 8 | zolotonosha
# Processing Record 11 of the Set 8 | santa cruz
# Processing Record 12 of the Set 8 | amga
# Processing Record 13 of the Set 8 | muroto
# Processing Record 14 of the Set 8 | kukurecani
# Processing Record 15 of the Set 8 | dzhusaly
# Processing Record 16 of the Set 8 | boende
# Processing Record 17 of the Set 8 | wamba
# Processing Record 18 of the Set 8 | sao felix do xingu
# Processing Record 19 of the Set 8 | sinop
# Processing Record 20 of the Set 8 | kloulklubed
# Processing Record 21 of the Set 8 | krapivinskiy
# Processing Record 22 of the Set 8 | camana
# Processing Record 23 of the Set 8 | klaksvik
# Processing Record 24 of the Set 8 | tapejara
# Processing Record 25 of the Set 8 | dharapuram
# Processing Record 26 of the Set 8 | tingrela
# City not found. Skipping...
# Processing Record 27 of the Set 8 | srednekolymsk
# Processing Record 28 of the Set 8 | primorskiy
# Processing Record 29 of the Set 8 | seddon
# Processing Record 30 of the Set 8 | praya
# Processing Record 31 of the Set 8 | piacabucu
# Processing Record 32 of the Set 8 | teguldet
# Processing Record 33 of the Set 8 | zhigansk
# Processing Record 34 of the Set 8 | namwala
# Processing Record 35 of the Set 8 | high rock
# Processing Record 36 of the Set 8 | pangkalanbuun
# Processing Record 37 of the Set 8 | valle de allende
# Processing Record 38 of the Set 8 | aflao
# Processing Record 39 of the Set 8 | sinnamary
# Processing Record 40 of the Set 8 | irmo
# Processing Record 41 of the Set 8 | flin flon
# Processing Record 42 of the Set 8 | beya
# Processing Record 43 of the Set 8 | pitkyaranta
# Processing Record 44 of the Set 8 | sanchazi
# Processing Record 45 of the Set 8 | caravelas
# Processing Record 46 of the Set 8 | jardim
# Processing Record 47 of the Set 8 | sao jose da coroa grande
# Processing Record 48 of the Set 8 | pokaran
# Processing Record 49 of the Set 8 | san jose
# Processing Record 50 of the Set 8 | reidsville
# Processing Record 1 of the Set 9 | roald
# Processing Record 2 of the Set 9 | darhan
# Processing Record 3 of the Set 9 | tumannyy
# Processing Record 4 of the Set 9 | oni
# Processing Record 5 of the Set 9 | jacareacanga
# Processing Record 6 of the Set 9 | redmond
# Processing Record 7 of the Set 9 | katsuura
# Processing Record 8 of the Set 9 | along
# Processing Record 9 of the Set 9 | charters towers
# Processing Record 10 of the Set 9 | tutoia
# Processing Record 11 of the Set 9 | oxapampa
# Processing Record 12 of the Set 9 | lompoc
# Processing Record 13 of the Set 9 | brewster
# Processing Record 14 of the Set 9 | hobyo
# Processing Record 15 of the Set 9 | coahuayana
# Processing Record 16 of the Set 9 | umm kaddadah
# Processing Record 17 of the Set 9 | nkowakowa
# Processing Record 18 of the Set 9 | yerbogachen
# Processing Record 19 of the Set 9 | fort frances
# Processing Record 20 of the Set 9 | yaring
# Processing Record 21 of the Set 9 | aripuana
# Processing Record 22 of the Set 9 | homer
# Processing Record 23 of the Set 9 | sulam
# Processing Record 24 of the Set 9 | tabou
# City not found. Skipping...
# Processing Record 25 of the Set 9 | walvis bay
# Processing Record 26 of the Set 9 | birobidzhan
# Processing Record 27 of the Set 9 | liverpool
# Processing Record 28 of the Set 9 | longyearbyen
# Processing Record 29 of the Set 9 | saint-augustin
# Processing Record 30 of the Set 9 | nalut
# Processing Record 31 of the Set 9 | marabba
# Processing Record 32 of the Set 9 | marcona
# Processing Record 33 of the Set 9 | boueni
# Processing Record 34 of the Set 9 | sakakah
# Processing Record 35 of the Set 9 | hambantota
# Processing Record 36 of the Set 9 | bundaberg
# Processing Record 37 of the Set 9 | khuzhir
# Processing Record 38 of the Set 9 | saint anthony
# Processing Record 39 of the Set 9 | mago
# Processing Record 40 of the Set 9 | buarcos
# Processing Record 41 of the Set 9 | norman wells
# Processing Record 42 of the Set 9 | phek
# Processing Record 43 of the Set 9 | chipinge
# Processing Record 44 of the Set 9 | pak phanang
# Processing Record 45 of the Set 9 | la libertad
# Processing Record 46 of the Set 9 | chagda
# Processing Record 47 of the Set 9 | puerto carreno
# Processing Record 48 of the Set 9 | challapata
# Processing Record 49 of the Set 9 | temaraia
# Processing Record 50 of the Set 9 | khonsa
# Processing Record 1 of the Set 10 | saurimo
# Processing Record 2 of the Set 10 | moussoro
# Processing Record 3 of the Set 10 | puerto cabello
# Processing Record 4 of the Set 10 | artyk
# Processing Record 5 of the Set 10 | nishihara
# Processing Record 6 of the Set 10 | daphne
# Processing Record 7 of the Set 10 | kollam
# Processing Record 8 of the Set 10 | baloda bazar
# Processing Record 9 of the Set 10 | viedma
# Processing Record 10 of the Set 10 | hamilton
# Processing Record 11 of the Set 10 | rocha
# Processing Record 12 of the Set 10 | sursk
# Processing Record 13 of the Set 10 | nehoiu
# Processing Record 14 of the Set 10 | kralendijk
# Processing Record 15 of the Set 10 | rorvik
# Processing Record 16 of the Set 10 | priiskovyy
# Processing Record 17 of the Set 10 | waingapu
# Processing Record 18 of the Set 10 | naples
# Processing Record 19 of the Set 10 | tabuk
# Processing Record 20 of the Set 10 | presidencia roque saenz pena
# Processing Record 21 of the Set 10 | oistins
# Processing Record 22 of the Set 10 | itaituba
# Processing Record 23 of the Set 10 | hue
# Processing Record 24 of the Set 10 | crossville
# Processing Record 25 of the Set 10 | lasa
# Processing Record 26 of the Set 10 | andenes
# Processing Record 27 of the Set 10 | lavrentiya
# Processing Record 28 of the Set 10 | mahajanga
# Processing Record 29 of the Set 10 | lanzhou
# Processing Record 30 of the Set 10 | senno
# Processing Record 31 of the Set 10 | okhotsk
# Processing Record 32 of the Set 10 | batemans bay
# Processing Record 33 of the Set 10 | saqqez
# Processing Record 34 of the Set 10 | marienburg
# Processing Record 35 of the Set 10 | aloleng
# Processing Record 36 of the Set 10 | zhanatas
# Processing Record 37 of the Set 10 | buraydah
# Processing Record 38 of the Set 10 | itoman
# Processing Record 39 of the Set 10 | sorvag
# Processing Record 40 of the Set 10 | alice springs
# Processing Record 41 of the Set 10 | creutzwald
# Processing Record 42 of the Set 10 | sayyan
# Processing Record 43 of the Set 10 | amapa
# Processing Record 44 of the Set 10 | natal
# Processing Record 45 of the Set 10 | vidim
# Processing Record 46 of the Set 10 | taguatinga
# Processing Record 47 of the Set 10 | yumen
# Processing Record 48 of the Set 10 | te anau
# Processing Record 49 of the Set 10 | sabha
# Processing Record 50 of the Set 10 | san cristobal
# Processing Record 1 of the Set 11 | shenjiamen
# Processing Record 2 of the Set 11 | winnemucca
# Processing Record 3 of the Set 11 | banmo
# City not found. Skipping...
# Processing Record 4 of the Set 11 | bongandanga
# Processing Record 5 of the Set 11 | phan rang
# Processing Record 6 of the Set 11 | ruatoria
# Processing Record 7 of the Set 11 | baruun-urt
# Processing Record 8 of the Set 11 | barreirinhas
# Processing Record 9 of the Set 11 | kismayo
# Processing Record 10 of the Set 11 | fairbanks
# Processing Record 11 of the Set 11 | tahta
# Processing Record 12 of the Set 11 | jhelum
# Processing Record 13 of the Set 11 | hervey bay
# Processing Record 14 of the Set 11 | lagos
# Processing Record 15 of the Set 11 | grand centre
# Processing Record 16 of the Set 11 | koumac
# Processing Record 17 of the Set 11 | santa maria
# Processing Record 18 of the Set 11 | kathmandu
# Processing Record 19 of the Set 11 | forbes
# Processing Record 20 of the Set 11 | asau
# Processing Record 21 of the Set 11 | la mana
# Processing Record 22 of the Set 11 | conceicao do araguaia
# Processing Record 23 of the Set 11 | nacala
# Processing Record 24 of the Set 11 | madimba
# Processing Record 25 of the Set 11 | gariaband
# Processing Record 26 of the Set 11 | avera
# Processing Record 27 of the Set 11 | gotsu
# Processing Record 28 of the Set 11 | moose factory
# Processing Record 29 of the Set 11 | macapa
# Processing Record 30 of the Set 11 | the valley
# Processing Record 31 of the Set 11 | carmen
# Processing Record 32 of the Set 11 | dabat
# Processing Record 33 of the Set 11 | komsomolskiy
# Processing Record 34 of the Set 11 | vao
# Processing Record 35 of the Set 11 | west wendover
# Processing Record 36 of the Set 11 | cambridge
# Processing Record 37 of the Set 11 | oksfjord
# Processing Record 38 of the Set 11 | medea
# Processing Record 39 of the Set 11 | kamenskoye
# Processing Record 40 of the Set 11 | ayagoz
# Processing Record 41 of the Set 11 | olafsvik
# Processing Record 42 of the Set 11 | carutapera
# Processing Record 43 of the Set 11 | novo oriente
# Processing Record 44 of the Set 11 | black forest
# Processing Record 45 of the Set 11 | kalmunai
# Processing Record 46 of the Set 11 | riviere-au-renard
# Processing Record 47 of the Set 11 | wasilla
# Processing Record 48 of the Set 11 | uyuni
# Processing Record 49 of the Set 11 | prince george
# Processing Record 50 of the Set 11 | nuristan
# City not found. Skipping...
# Processing Record 1 of the Set 12 | bassano
# Processing Record 2 of the Set 12 | biala podlaska
# Processing Record 3 of the Set 12 | hun
# Processing Record 4 of the Set 12 | mimoso do sul
# Processing Record 5 of the Set 12 | kargat
# Processing Record 6 of the Set 12 | broken hill
# Processing Record 7 of the Set 12 | shache
# Processing Record 8 of the Set 12 | parrsboro
# Processing Record 9 of the Set 12 | gelibolu
# Processing Record 10 of the Set 12 | alberton
# Processing Record 11 of the Set 12 | tafalla
# Processing Record 12 of the Set 12 | stokmarknes
# Processing Record 13 of the Set 12 | bageshwar
# Processing Record 14 of the Set 12 | road town
# Processing Record 15 of the Set 12 | miracema
# Processing Record 16 of the Set 12 | tilichiki
# Processing Record 17 of the Set 12 | punta alta
# Processing Record 18 of the Set 12 | mapiripan
# Processing Record 19 of the Set 12 | petatlan
# Processing Record 20 of the Set 12 | calvia
# Processing Record 21 of the Set 12 | lianran
# Processing Record 22 of the Set 12 | am timan
# Processing Record 23 of the Set 12 | hamilton
# Processing Record 24 of the Set 12 | korhogo
# City not found. Skipping...
# Processing Record 25 of the Set 12 | altinopolis
# Processing Record 26 of the Set 12 | fort nelson
# Processing Record 27 of the Set 12 | my tho
# Processing Record 28 of the Set 12 | mocuba
# Processing Record 29 of the Set 12 | toliary
# Processing Record 30 of the Set 12 | udachnyy
# Processing Record 31 of the Set 12 | lashio
# City not found. Skipping...
# Processing Record 32 of the Set 12 | poum
# Processing Record 33 of the Set 12 | sawakin
# Processing Record 34 of the Set 12 | eureka
# Processing Record 35 of the Set 12 | stornoway
# Processing Record 36 of the Set 12 | anaconda
# Processing Record 37 of the Set 12 | fairview
# Processing Record 38 of the Set 12 | alyangula
# Processing Record 39 of the Set 12 | iskateley
# Processing Record 40 of the Set 12 | imbituba
# Processing Record 41 of the Set 12 | novikovo
# Processing Record 42 of the Set 12 | maridi
# Processing Record 43 of the Set 12 | watsa
# Processing Record 44 of the Set 12 | grakhovo
# Processing Record 45 of the Set 12 | acarau
# Processing Record 46 of the Set 12 | adrar
# Processing Record 47 of the Set 12 | mwaya
# Processing Record 48 of the Set 12 | melilla
# Processing Record 49 of the Set 12 | noumea
# Processing Record 50 of the Set 12 | laguna
# Processing Record 1 of the Set 13 | egvekinot
# Processing Record 2 of the Set 13 | garissa
# Processing Record 3 of the Set 13 | merauke
# Processing Record 4 of the Set 13 | weiser
# Processing Record 5 of the Set 13 | lolua
# Processing Record 6 of the Set 13 | tasbuget
# Processing Record 7 of the Set 13 | pyapon
# City not found. Skipping...
# Processing Record 8 of the Set 13 | gushikawa
# Processing Record 9 of the Set 13 | starkville
# Processing Record 10 of the Set 13 | golden
# Processing Record 11 of the Set 13 | filotion
# Processing Record 12 of the Set 13 | willmar
# Processing Record 13 of the Set 13 | bambanglipuro
# Processing Record 14 of the Set 13 | half moon bay
# Processing Record 15 of the Set 13 | belyy yar
# Processing Record 16 of the Set 13 | reconquista
# Processing Record 17 of the Set 13 | papetoai
# Processing Record 18 of the Set 13 | manaus
# Processing Record 19 of the Set 13 | wulanhaote
# Processing Record 20 of the Set 13 | blyznyuky
# Processing Record 21 of the Set 13 | lishu
# Processing Record 22 of the Set 13 | ulcinj
# Processing Record 23 of the Set 13 | san quintin
# Processing Record 24 of the Set 13 | yinchuan
# Processing Record 25 of the Set 13 | ust-omchug
# Processing Record 26 of the Set 13 | southbridge
# Processing Record 27 of the Set 13 | karratha
# Processing Record 28 of the Set 13 | sechura
# Processing Record 29 of the Set 13 | rosetta
# Processing Record 30 of the Set 13 | pangnirtung
# Processing Record 31 of the Set 13 | the pas
# Processing Record 32 of the Set 13 | tateyama
# Processing Record 33 of the Set 13 | myitkyina
# City not found. Skipping...
# Processing Record 34 of the Set 13 | morondava
# Processing Record 35 of the Set 13 | galveston
# Processing Record 36 of the Set 13 | coquimbo
# Processing Record 37 of the Set 13 | pangody
# Processing Record 38 of the Set 13 | college
# Processing Record 39 of the Set 13 | changde
# Processing Record 40 of the Set 13 | nakamura
# Processing Record 41 of the Set 13 | tsaratanana
# Processing Record 42 of the Set 13 | barra
# Processing Record 43 of the Set 13 | la primavera
# Processing Record 44 of the Set 13 | naifaru
# Processing Record 45 of the Set 13 | kankan
# Processing Record 46 of the Set 13 | makakilo city
# Processing Record 47 of the Set 13 | harker heights
# Processing Record 48 of the Set 13 | bela palanka
# Processing Record 49 of the Set 13 | zhangjiakou
# Processing Record 50 of the Set 13 | san patricio
# Processing Record 1 of the Set 14 | challans
# Processing Record 2 of the Set 14 | cranbourne
# Processing Record 3 of the Set 14 | svetlyy
# Processing Record 4 of the Set 14 | martinsville
# Processing Record 5 of the Set 14 | nzega
# Processing Record 6 of the Set 14 | zhuhai
# Processing Record 7 of the Set 14 | kindu
# Processing Record 8 of the Set 14 | sawtell
# Processing Record 9 of the Set 14 | cayenne
# Processing Record 10 of the Set 14 | havelock
# Processing Record 11 of the Set 14 | ygatimi
# Processing Record 12 of the Set 14 | port lincoln
# Processing Record 13 of the Set 14 | brae
# Processing Record 14 of the Set 14 | hanko
# Processing Record 15 of the Set 14 | ballina
# Processing Record 16 of the Set 14 | palimbang
# Processing Record 17 of the Set 14 | tabiauea
# Processing Record 18 of the Set 14 | kamenka
# Processing Record 19 of the Set 14 | pervomayskoye
# Processing Record 20 of the Set 14 | gorno-chuyskiy
# Processing Record 21 of the Set 14 | nizhneangarsk
# Processing Record 22 of the Set 14 | bisira
# Processing Record 23 of the Set 14 | darnah
# Processing Record 24 of the Set 14 | palu
# Processing Record 25 of the Set 14 | marzuq
# Processing Record 26 of the Set 14 | hamada
# Processing Record 27 of the Set 14 | kletskaya
# Processing Record 28 of the Set 14 | cabedelo
# Processing Record 29 of the Set 14 | sikea
# Processing Record 30 of the Set 14 | skelleftea
# Processing Record 31 of the Set 14 | nadym
# Processing Record 32 of the Set 14 | viseu
# Processing Record 33 of the Set 14 | prestea
# Processing Record 34 of the Set 14 | sale
# Processing Record 35 of the Set 14 | yanchukan
# Processing Record 36 of the Set 14 | aldama
# Processing Record 37 of the Set 14 | dudinka
# Processing Record 38 of the Set 14 | iralaya
# Processing Record 39 of the Set 14 | tamandare
# Processing Record 40 of the Set 14 | nizhniy kuranakh
# Processing Record 41 of the Set 14 | mecca
# Processing Record 42 of the Set 14 | comodoro rivadavia
# Processing Record 43 of the Set 14 | urucui
# Processing Record 44 of the Set 14 | bantry
# Processing Record 45 of the Set 14 | fez
# Processing Record 46 of the Set 14 | kegayli
# City not found. Skipping...
# Processing Record 47 of the Set 14 | gat
# Processing Record 48 of the Set 14 | pontes e lacerda
# Processing Record 49 of the Set 14 | hailey
# Processing Record 50 of the Set 14 | alice town
# Processing Record 1 of the Set 15 | westport
# Processing Record 2 of the Set 15 | northam
# Processing Record 3 of the Set 15 | daru
# Processing Record 4 of the Set 15 | tieli
# Processing Record 5 of the Set 15 | zalantun
# Processing Record 6 of the Set 15 | jiblah
# Processing Record 7 of the Set 15 | doctor arroyo
# Processing Record 8 of the Set 15 | ajdabiya
# Processing Record 9 of the Set 15 | vila franca do campo
# Processing Record 10 of the Set 15 | zhezkazgan
# Processing Record 11 of the Set 15 | port moresby
# Processing Record 12 of the Set 15 | torrijos
# Processing Record 13 of the Set 15 | palmas
# Processing Record 14 of the Set 15 | mitsamiouli
# Processing Record 15 of the Set 15 | mbala
# Processing Record 16 of the Set 15 | chimoio
# Processing Record 17 of the Set 15 | nador
# Processing Record 18 of the Set 15 | great yarmouth
# Processing Record 19 of the Set 15 | chenzhou
# Processing Record 20 of the Set 15 | luhyny
# Processing Record 21 of the Set 15 | colombo
# Processing Record 22 of the Set 15 | scottsburgh
# Processing Record 23 of the Set 15 | turayf
# Processing Record 24 of the Set 15 | sola
# Processing Record 25 of the Set 15 | muros
# Processing Record 26 of the Set 15 | deder
# Processing Record 27 of the Set 15 | yatou
# Processing Record 28 of the Set 15 | leningradskiy
# Processing Record 29 of the Set 15 | shuangyang
# Processing Record 30 of the Set 15 | sur
# Processing Record 31 of the Set 15 | itapolis
# Processing Record 32 of the Set 15 | sokoto
# Processing Record 33 of the Set 15 | brahmapuri
# Processing Record 34 of the Set 15 | wentzville
# Processing Record 35 of the Set 15 | fort morgan
# Processing Record 36 of the Set 15 | aljezur
# Processing Record 37 of the Set 15 | xiongzhou
# Processing Record 38 of the Set 15 | seleus
# Processing Record 39 of the Set 15 | sakata
# Processing Record 40 of the Set 15 | troitskoye
# Processing Record 41 of the Set 15 | mezen
# Processing Record 42 of the Set 15 | argetoaia
# Processing Record 43 of the Set 15 | ongandjera
# Processing Record 44 of the Set 15 | margate
# Processing Record 45 of the Set 15 | inirida
# Processing Record 46 of the Set 15 | fort-shevchenko
# Processing Record 47 of the Set 15 | aabybro
# Processing Record 48 of the Set 15 | burnie
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 729

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Xining      CN  36.62  101.77     50.18        60          40
# 1        Vaini      TO -21.20 -175.20     75.20        94          90
# 2    Cape Town      ZA -33.93   18.42     61.00        93          75
# 3  East London      ZA -33.93   18.42     61.00        93          75
# 4      Hualmay      PE -11.10  -77.61     61.57        77          41
#
#    Wind Speed Current Description
# 0        2.06    scattered clouds
# 1       11.41          light rain
# 2       17.22       broken clouds
# 3       17.22       broken clouds
# 4       11.68    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")

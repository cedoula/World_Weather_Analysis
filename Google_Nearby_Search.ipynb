# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params =  {
    "type": "lodging",
    "radius": 5000,
    "key": g_key,
    #"location": "48.864716,2.349014"
    "location": "-16.48,-151.75"
}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()
hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHwEAAJgHmGVLAC6XEIQxeD7Vzqifzi-q616LHM7LwWCd70uXfOKkIiNT_xGa3IHt_uuPl7jjQKmPv0eUhLe7Y5W1qkI-YuMcQtgtec144w2YsFkjgzIHamVbRO-5stWPLQWAF7UhTkfyfxytyHxzoCTgI_qt66PiX323tVAniWtkVt4u0HWRIaMzQhwbVZT93Rv3YOqNs2zeEjaQi51fQT5fXEHHRqpFuhR-2Oan4QpjHvqWAvR1Ltq3TlRqtFr5rWnop2MSzM0XhR7KsjKy55tQP9yUXl3ls7LhtQ4dasI6E0WTQzTZfKXR6Fth73brNJWvIUCFLfIPjN3gnVYaB_XZ23sVG_sYIrU5mUPMUmibtWVZLFLKsThwoGJVSw6wZ-pJUxIQ8RYIFh1za7R76HTJKgXsuRoUDY0Lo1rBm7Zb269av8f7q_yxkMo',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4759407, 'lng': -151.7724793},
#     'viewport': {'northeast': {'lat': -16.47405801970849,
#       'lng': -151.7710643197085},
#      'southwest': {'lat': -16.4767559802915, 'lng': -151.7737622802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Bora-Bora Pearl Beach Resort & Spa',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 933,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104246194359653987357">Bora Bora Pearl Beach Resort &amp; Spa</a>'],
#      'photo_reference': 'CkQ0AAAA6TcD4Pim8oSTb4kKDU_YTJKoEwqocBUnhCprGqbUXx9ouKzTcnAtzDcKQPlEMpxNFyY98tRs6fAcIDeTlSht4hIQW7Cm9aAcyv4hOaloCcTpAxoU5rHISnfKqZK4V7haG8jKidyCzf8',
#      'width': 1400}],
#    'place_id': 'ChIJH4mb5268vXYRv4OyGEc8kr0',
#    'plus_code': {'compound_code': 'G6FH+J2 Bora-Bora, French Polynesia',
#     'global_code': '53MCG6FH+J2'},
#    'rating': 4.7,
#    'reference': 'ChIJH4mb5268vXYRv4OyGEc8kr0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 571,
#    'vicinity': 'Vaitape'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4501748, 'lng': -151.736834},
#     'viewport': {'northeast': {'lat': -16.4488258197085,
#       'lng': -151.7354850197085},
#      'southwest': {'lat': -16.4515237802915, 'lng': -151.7381829802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Pension Alice et Raphael Bora-Bora',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117707430086076229400">Raphael Bernabé</a>'],
#      'photo_reference': 'CkQ0AAAAEPvFQs4S1KOr0nUBJmurapqABVGgvmNc3kvrHvSwn1z0mbCXwyVkLBzSjge05upMIHAGW8WwAukKLIqasXSxExIQOaIZKflx-8SrWh_Is1bV8BoUhpq-mbI84J70mfwoGqOml2ZQass',
#      'width': 640}],
#    'place_id': 'ChIJZU0_a9C9vXYR5iX0lQQGXkE',
#    'plus_code': {'compound_code': 'G7X7+W7 Bora-Bora, French Polynesia',
#     'global_code': '53MCG7X7+W7'},
#    'rating': 4.8,
#    'reference': 'ChIJZU0_a9C9vXYR5iX0lQQGXkE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 22,
#    'vicinity': 'Motu Ome'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.449585, 'lng': -151.766166},
#     'viewport': {'northeast': {'lat': -16.4482360197085,
#       'lng': -151.7648170197085},
#      'southwest': {'lat': -16.4509339802915, 'lng': -151.7675149802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Blue Heaven Island',
#    'photos': [{'height': 480,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100257434589126011137">blue heaven island</a>'],
#      'photo_reference': 'CkQ0AAAAGwZvGmnf6q9qKoZNUWiV9RjqVmgyfX4edcMwJoKFwi90ZeeWoKLV-ODA_NDumgdZtZ7G2d81-QUcwsi3wmd76hIQPyTfReMoeU5gzwX2JAEWXxoUlje_Y4p8Ui9qOBRO85LY23OgaCg',
#      'width': 640}],
#    'place_id': 'ChIJi2A1QiG8vXYR2k315sjeyqg',
#    'plus_code': {'compound_code': 'H62M+5G Bora-Bora, French Polynesia',
#     'global_code': '53MCH62M+5G'},
#    'rating': 4.8,
#    'reference': 'ChIJi2A1QiG8vXYR2k315sjeyqg',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 21,
#    'vicinity': 'French Polynesia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4729859, 'lng': -151.7058542},
#     'viewport': {'northeast': {'lat': -16.4716369197085,
#       'lng': -151.7045052197085},
#      'southwest': {'lat': -16.4743348802915, 'lng': -151.7072031802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Four Seasons Resort Bora Bora',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 720,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101218562484249582693">Four Seasons Resort Bora Bora</a>'],
#      'photo_reference': 'CkQ0AAAAl4sUHTCdz96wSS9PjIaM7KDa8YrobuhbvQu-koUh-bgSaKyA3nzb4skfVYKLuFTujeJwZYfr_yUX6pRhy-E9DxIQt72sl214U0p8Lu15oWNGqxoUtaA_ZWcHZdP8FT-uUS4lTPkpSMM',
#      'width': 1280}],
#    'place_id': 'ChIJB_VVzoa9vXYRguWsYU0H8eU',
#    'plus_code': {'compound_code': 'G7GV+RM Bora-Bora, French Polynesia',
#     'global_code': '53MCG7GV+RM'},
#    'rating': 4.7,
#    'reference': 'ChIJB_VVzoa9vXYRguWsYU0H8eU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 555,
#    'vicinity': 'French Polynesia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.46620799999999, 'lng': -151.7509854},
#     'viewport': {'northeast': {'lat': -16.46474586970849,
#       'lng': -151.7496928697085},
#      'southwest': {'lat': -16.4674438302915, 'lng': -151.7523908302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Bora Bora Bungalow - Here Moana',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106588576173071631542">Denis Renko</a>'],
#      'photo_reference': 'CkQ0AAAAchpagBSfJlbz5tHP4iFwRsEPVz8Ss1RXJAamrwKxzhgUkv7lmuxNQCB4fSzQwFTn4FhriuGL35yJFr2YbgizuhIQTsA_x8VT1r7rxU8ilfXb5BoUK1t57A7syqv_U-pV_3jMJ7jFMME',
#      'width': 4032}],
#    'place_id': 'ChIJTWvTWkq8vXYR4xg4AfGM7BU',
#    'plus_code': {'compound_code': 'G6MX+GJ Bora-Bora, French Polynesia',
#     'global_code': '53MCG6MX+GJ'},
#    'rating': 5,
#    'reference': 'ChIJTWvTWkq8vXYR4xg4AfGM7BU',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 25,
#    'vicinity': 'Bungalow 12, BP 818 Bora Bora Main Road'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4976468, 'lng': -151.7545068},
#     'viewport': {'northeast': {'lat': -16.4963299197085,
#       'lng': -151.7530945197085},
#      'southwest': {'lat': -16.4990278802915, 'lng': -151.7557924802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Sunset Hill Lodge',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111161129596882168438">Sunset Hill Lodge</a>'],
#      'photo_reference': 'CkQ0AAAARhu1d8McniHyJfIEvYBc03Y23o4TLzX8J2VJK3HL7Ox1dzkDDNbDuuioqzh4gqOhnleYZ3kMcFKBbm50Xy6EdhIQqtbCZ77slg2cWODQhBDF5hoUAuamQ0FqN5q8lOcsrKJeo9-RN-4',
#      'width': 2048}],
#    'place_id': 'ChIJVy2zueS8vXYRf18-bl1BwGQ',
#    'plus_code': {'compound_code': 'G62W+W5 Bora-Bora, French Polynesia',
#     'global_code': '53MCG62W+W5'},
#    'rating': 4.5,
#    'reference': 'ChIJVy2zueS8vXYRf18-bl1BwGQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 46,
#    'vicinity': 'Vaitape'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.49885039999999, 'lng': -151.7570304},
#     'viewport': {'northeast': {'lat': -16.4974196697085,
#       'lng': -151.7556685197085},
#      'southwest': {'lat': -16.5001176302915, 'lng': -151.7583664802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Oa Oa Lodge',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 1367,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100645999583288005221">Oa Oa Lodge</a>'],
#      'photo_reference': 'CkQ0AAAAGUiMNaKbEk2M4Z3wEyOxWvypyKwqfJXddkO4NAEpuF1G6rlVILmW6o2GMucD0ivjxdgxZc9OOfb87iWKFOLFJBIQcDquyQwKerBrmVI6gBBD1hoUCk5JvBMDr1qMmT6STGE6lnc3R0E',
#      'width': 2048}],
#    'place_id': 'ChIJ00z-FuW8vXYRGhHqMHIHi08',
#    'plus_code': {'compound_code': 'G62V+F5 Bora-Bora, French Polynesia',
#     'global_code': '53MCG62V+F5'},
#    'rating': 4.1,
#    'reference': 'ChIJ00z-FuW8vXYRGhHqMHIHi08',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 69,
#    'vicinity': 'Vaitape'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4569942, 'lng': -151.7706299},
#     'viewport': {'northeast': {'lat': -16.4556452197085,
#       'lng': -151.7692809197085},
#      'southwest': {'lat': -16.4583431802915, 'lng': -151.7719788802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Bora Bora Ecolodge - Pension du Motu',
#    'photos': [{'height': 2825,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109274380857936682297">bernardo tejada</a>'],
#      'photo_reference': 'CkQzAAAAYltRuOs2Q9twNOZnZYrp2S7VyRPV4Z6NrMCaNObSaNL3lZAllBwPpX3r7G-JG0hJx7ROJGYssnnscB6v_8aTlxIQsVQlmZ1NuX3oqbugFBy3cxoUW4DDo-kB7CfsdG4fbqoImlM4Asg',
#      'width': 4122}],
#    'place_id': 'ChIJ4UZKVj28vXYRmYKv7u_E5R4',
#    'plus_code': {'compound_code': 'G6VH+6P Bora-Bora, French Polynesia',
#     'global_code': '53MCG6VH+6P'},
#    'rating': 5,
#    'reference': 'ChIJ4UZKVj28vXYRmYKv7u_E5R4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5,
#    'vicinity': 'French Polynesia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.5062723, 'lng': -151.7495305},
#     'viewport': {'northeast': {'lat': -16.5050244697085,
#       'lng': -151.7481562697085},
#      'southwest': {'lat': -16.5077224302915, 'lng': -151.7508542302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Pension Robert et Tina',
#    'place_id': 'ChIJVVVVZeC8vXYRrPjhjYGwzf8',
#    'rating': 3.5,
#    'reference': 'ChIJVVVVZeC8vXYRrPjhjYGwzf8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Vaitape'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.5216154, 'lng': -151.7323933},
#     'viewport': {'northeast': {'lat': -16.5202185697085,
#       'lng': -151.7310152197085},
#      'southwest': {'lat': -16.5229165302915, 'lng': -151.7337131802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Bora Faretai Love',
#    'photos': [{'height': 1536,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109330373654559131709">Milona Vane</a>'],
#      'photo_reference': 'CkQ0AAAAEw_aW1CM9q3vvNdZbZD_Bkho4qUCGnvk4yoytNjqV-pIwJ77sSq70P1Mj__nBVBoICm5W4RZda7PX-xrv6c9HhIQBJtrC2D5X0nOGs1VG2e6wBoURCfbvI4OE5Qu18AWsjVS59dCP8I',
#      'width': 2048}],
#    'place_id': 'ChIJQ57ayzO9vXYRV1xXQbigJqE',
#    'plus_code': {'compound_code': 'F7H9+92 Bora-Bora, French Polynesia',
#     'global_code': '53MCF7H9+92'},
#    'rating': 4,
#    'reference': 'ChIJQ57ayzO9vXYRV1xXQbigJqE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 11,
#    'vicinity': 'Bora-Bora'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4789605, 'lng': -151.7525535},
#     'viewport': {'northeast': {'lat': -16.4777446197085,
#       'lng': -151.7512771697085},
#      'southwest': {'lat': -16.4804425802915, 'lng': -151.7539751302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Teina Pascale',
#    'place_id': 'ChIJk7-1sf29vXYR9VYHPUQtVJc',
#    'plus_code': {'compound_code': 'G6CW+CX Bora-Bora, French Polynesia',
#     'global_code': '53MCG6CW+CX'},
#    'reference': 'ChIJk7-1sf29vXYR9VYHPUQtVJc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Bora-Bora'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4846487, 'lng': -151.7446821},
#     'viewport': {'northeast': {'lat': -16.48324286970849,
#       'lng': -151.7433190197085},
#      'southwest': {'lat': -16.4859408302915, 'lng': -151.7460169802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': "Bora Bora Holiday Home, Fare o'Eden",
#    'place_id': 'ChIJleAKgaq9vXYR6GhjKV1PHy0',
#    'plus_code': {'compound_code': 'G784+44 Bora-Bora, French Polynesia',
#     'global_code': '53MCG784+44'},
#    'rating': 1,
#    'reference': 'ChIJleAKgaq9vXYR6GhjKV1PHy0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Bora-Bora'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.48467, 'lng': -151.74431},
#     'viewport': {'northeast': {'lat': -16.4833069197085,
#       'lng': -151.7429487197085},
#      'southwest': {'lat': -16.4860048802915, 'lng': -151.7456466802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Bora Bora Bungalove',
#    'photos': [{'height': 2800,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113891135027852008740">nathalie Coho</a>'],
#      'photo_reference': 'CkQ0AAAAiRj-CeXlrLcpk2--Y1m2L5_jOZmAgn5No4_4fuqf_LlOJEIktBSqj8Kg2gzRZbTG_-dKWstWR3FeF_A_ECtl7RIQ14P0DbBtJmh6O48LuRhnphoUboKx4LhRY5aLSSUwFltzJQXBoxE',
#      'width': 4976}],
#    'place_id': 'ChIJb8G-f6q9vXYRvu9jLyhWx28',
#    'plus_code': {'compound_code': 'G784+47 Bora-Bora, French Polynesia',
#     'global_code': '53MCG784+47'},
#    'rating': 4.9,
#    'reference': 'ChIJb8G-f6q9vXYRvu9jLyhWx28',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 28,
#    'vicinity': 'French Polynesia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4724034, 'lng': -151.7447392},
#     'viewport': {'northeast': {'lat': -16.4710907197085,
#       'lng': -151.7434677197085},
#      'southwest': {'lat': -16.4737886802915, 'lng': -151.7461656802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Faatane Faanui',
#    'photos': [{'height': 823,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103956249885868522751">Vaite Wernert</a>'],
#      'photo_reference': 'CkQ0AAAA--tS5JEyPfjzbcAwJyDPjl0tsUHHuZDmnoLHvmQt1cvDAuyfKzaczFr6Ax1n6bThPTJYKLRWZQfG587K8wMmlxIQyKWininIsWqhfYcmHVsBmhoUMGcbHOUC2Z9qdOXEbpyS8Ar3V-E',
#      'width': 1200}],
#    'place_id': 'ChIJzVYeyJ69vXYR9d1YO1rxkE8',
#    'plus_code': {'compound_code': 'G7H4+24 Bora-Bora, French Polynesia',
#     'global_code': '53MCG7H4+24'},
#    'reference': 'ChIJzVYeyJ69vXYR9d1YO1rxkE8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Bora-Bora'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4743038, 'lng': -151.7402463},
#     'viewport': {'northeast': {'lat': -16.47294301970849,
#       'lng': -151.7388612197085},
#      'southwest': {'lat': -16.4756409802915, 'lng': -151.7415591802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Bora Vaite Lodge ( chambres d’hôtes)',
#    'place_id': 'ChIJwVrABRS9vXYRsNavNsL5VVI',
#    'plus_code': {'compound_code': 'G7G5+7W Bora-Bora, French Polynesia',
#     'global_code': '53MCG7G5+7W'},
#    'reference': 'ChIJwVrABRS9vXYRsNavNsL5VVI',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Faatane, Faanui, Bora-Bora'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4901518, 'lng': -151.7542594},
#     'viewport': {'northeast': {'lat': -16.48873691970849,
#       'lng': -151.7528237197085},
#      'southwest': {'lat': -16.4914348802915, 'lng': -151.7555216802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Chez Michel',
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115809035518279877325">Sébatien Jean</a>'],
#      'photo_reference': 'CkQ0AAAAgymfpm141YDMKcIJZcv8ZfBY5fUAWJVjWCdyEg9Fsx0ykIiRLFs0Qg6XLZf_WsINmYt7ycqBX_LiFEki92h1_RIQ0FNyWaz6cab84tvGzlyXjRoUwf5JipcpdlPJp0DFr78lUlBDabk',
#      'width': 4032}],
#    'place_id': 'ChIJex7KOPm8vXYRSri1C29nic4',
#    'plus_code': {'compound_code': 'G65W+W7 Bora-Bora, French Polynesia',
#     'global_code': '53MCG65W+W7'},
#    'rating': 4.3,
#    'reference': 'ChIJex7KOPm8vXYRSri1C29nic4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': 'Bora-Bora, Polynésie française'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4737653, 'lng': -151.7404551},
#     'viewport': {'northeast': {'lat': -16.4724032197085,
#       'lng': -151.7390601197085},
#      'southwest': {'lat': -16.4751011802915, 'lng': -151.7417580802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Bora Vaite Lodge',
#    'photos': [{'height': 692,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103956249885868522751">Vaite Wernert</a>'],
#      'photo_reference': 'CkQ0AAAASxC1m77BNf22Rd8h8s7f-Eds8LWgjtRafnHNZbKWsT-TFaYU7W3dS6uXP8Gj833YrAnT5T2uoAkFMYMCbJSq3RIQYQ_HV5ucImThTMgtPtyBVxoUAadwLRoEuY1DO4BIZ43-IUIxlNE',
#      'width': 1200}],
#    'place_id': 'ChIJg9sGdxG9vXYRV4gT69Uuofo',
#    'plus_code': {'compound_code': 'G7G5+FR Bora-Bora, French Polynesia',
#     'global_code': '53MCG7G5+FR'},
#    'rating': 5,
#    'reference': 'ChIJg9sGdxG9vXYRV4gT69Uuofo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'French Polynesia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4875962, 'lng': -151.7407595},
#     'viewport': {'northeast': {'lat': -16.4860598697085,
#       'lng': -151.7393355697085},
#      'southwest': {'lat': -16.4887578302915, 'lng': -151.7420335302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Tefaremaolodge',
#    'place_id': 'ChIJETj5qh29vXYRycfRsgFIl5k',
#    'plus_code': {'compound_code': 'G765+XM Bora-Bora, French Polynesia',
#     'global_code': '53MCG765+XM'},
#    'reference': 'ChIJETj5qh29vXYRycfRsgFIl5k',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': ''},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4875962, 'lng': -151.7407595},
#     'viewport': {'northeast': {'lat': -16.4860598697085,
#       'lng': -151.7393355697085},
#      'southwest': {'lat': -16.4887578302915, 'lng': -151.7420335302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Bora Vaite Lodge',
#    'photos': [{'height': 1335,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114181831206117554023">Tahitiguide Tahitiguide</a>'],
#      'photo_reference': 'CkQ0AAAAUFVQHlG9ffMsi-amDvD7mZCNcOWtuTVdcRjL_s8byOChDqFfN-TBxltC7TGQ9oP8hdAYIePJuG5trczPfp5frxIQ7WUSWbJztnDUxpo2bh1uTRoUV_xp-Gl8PklCvKQlZLYPQdj_doM',
#      'width': 2000}],
#    'place_id': 'ChIJiXylNj69vXYR0PeqcPepXN8',
#    'plus_code': {'compound_code': 'G765+XM Bora-Bora, French Polynesia',
#     'global_code': '53MCG765+XM'},
#    'rating': 5,
#    'reference': 'ChIJiXylNj69vXYR0PeqcPepXN8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'French Polynesia'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -16.4875962, 'lng': -151.7407595},
#     'viewport': {'northeast': {'lat': -16.4860598697085,
#       'lng': -151.7393355697085},
#      'southwest': {'lat': -16.4887578302915, 'lng': -151.7420335302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Fare Hibiscus, Bungalow 14',
#    'place_id': 'ChIJy8HXwa-9vXYRjC1Ml6_ZoDA',
#    'plus_code': {'compound_code': 'G765+XM Bora-Bora, French Polynesia',
#     'global_code': '53MCG765+XM'},
#    'reference': 'ChIJy8HXwa-9vXYRjC1Ml6_ZoDA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'French Polynesia'}],
#  'status': 'OK'}

# %%
len(hotels["results"])
# Out:
# 20

# %%
hotels["results"][0]["name"]
# Out:
# 'Cititel Penang'

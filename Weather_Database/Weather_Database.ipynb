# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 754

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | husavik
# Processing Record 2 of the Set 1 | inhambane
# Processing Record 3 of the Set 1 | sao joao da barra
# Processing Record 4 of the Set 1 | rikitea
# Processing Record 5 of the Set 1 | arraial do cabo
# Processing Record 6 of the Set 1 | busselton
# Processing Record 7 of the Set 1 | khonuu
# City not found. Skipping...
# Processing Record 8 of the Set 1 | impfondo
# Processing Record 9 of the Set 1 | aurangabad
# Processing Record 10 of the Set 1 | tuktoyaktuk
# Processing Record 11 of the Set 1 | biltine
# Processing Record 12 of the Set 1 | port elizabeth
# Processing Record 13 of the Set 1 | jamestown
# Processing Record 14 of the Set 1 | port lincoln
# Processing Record 15 of the Set 1 | luderitz
# Processing Record 16 of the Set 1 | barrow
# Processing Record 17 of the Set 1 | saint anthony
# Processing Record 18 of the Set 1 | victoria point
# Processing Record 19 of the Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of the Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of the Set 1 | qaanaaq
# City not found. Skipping...
# Processing Record 22 of the Set 1 | kapaa
# Processing Record 23 of the Set 1 | kamaishi
# Processing Record 24 of the Set 1 | tarudant
# City not found. Skipping...
# Processing Record 25 of the Set 1 | altay
# Processing Record 26 of the Set 1 | katsuura
# Processing Record 27 of the Set 1 | manresa
# Processing Record 28 of the Set 1 | hasaki
# Processing Record 29 of the Set 1 | pinawa
# Processing Record 30 of the Set 1 | attawapiskat
# Processing Record 31 of the Set 1 | adrar
# Processing Record 32 of the Set 1 | vestmannaeyjar
# Processing Record 33 of the Set 1 | naze
# Processing Record 34 of the Set 1 | zhigansk
# Processing Record 35 of the Set 1 | cape town
# Processing Record 36 of the Set 1 | dikson
# Processing Record 37 of the Set 1 | concarneau
# Processing Record 38 of the Set 1 | alice springs
# Processing Record 39 of the Set 1 | samarai
# Processing Record 40 of the Set 1 | sitka
# Processing Record 41 of the Set 1 | bubaque
# Processing Record 42 of the Set 1 | mataura
# Processing Record 43 of the Set 1 | cassilandia
# Processing Record 44 of the Set 1 | isangel
# Processing Record 45 of the Set 1 | lolua
# City not found. Skipping...
# Processing Record 46 of the Set 1 | kirakira
# Processing Record 47 of the Set 1 | rawson
# Processing Record 48 of the Set 1 | ponoka
# Processing Record 49 of the Set 1 | grindavik
# Processing Record 50 of the Set 1 | sentyabrskiy
# Processing Record 1 of the Set 2 | mackay
# Processing Record 2 of the Set 2 | irtyshskiy
# Processing Record 3 of the Set 2 | lebu
# Processing Record 4 of the Set 2 | la ronge
# Processing Record 5 of the Set 2 | jampur
# Processing Record 6 of the Set 2 | padang
# Processing Record 7 of the Set 2 | puerto ayora
# Processing Record 8 of the Set 2 | maanshan
# Processing Record 9 of the Set 2 | pacific grove
# Processing Record 10 of the Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 11 of the Set 2 | ushuaia
# Processing Record 12 of the Set 2 | grand centre
# Processing Record 13 of the Set 2 | carnarvon
# Processing Record 14 of the Set 2 | albany
# Processing Record 15 of the Set 2 | santa marta
# Processing Record 16 of the Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of the Set 2 | chuy
# Processing Record 18 of the Set 2 | atuona
# Processing Record 19 of the Set 2 | bredasdorp
# Processing Record 20 of the Set 2 | vaini
# Processing Record 21 of the Set 2 | airai
# Processing Record 22 of the Set 2 | mbeya
# Processing Record 23 of the Set 2 | lonavale
# Processing Record 24 of the Set 2 | bay city
# Processing Record 25 of the Set 2 | bambous virieux
# Processing Record 26 of the Set 2 | punta arenas
# Processing Record 27 of the Set 2 | karachi
# Processing Record 28 of the Set 2 | ponta do sol
# Processing Record 29 of the Set 2 | victoria
# Processing Record 30 of the Set 2 | salalah
# Processing Record 31 of the Set 2 | rio grande
# Processing Record 32 of the Set 2 | lesozavodsk
# Processing Record 33 of the Set 2 | marrakesh
# City not found. Skipping...
# Processing Record 34 of the Set 2 | severo-kurilsk
# Processing Record 35 of the Set 2 | pocoes
# Processing Record 36 of the Set 2 | port alfred
# Processing Record 37 of the Set 2 | upernavik
# City not found. Skipping...
# Processing Record 38 of the Set 2 | hami
# Processing Record 39 of the Set 2 | nizhneyansk
# Processing Record 40 of the Set 2 | kruisfontein
# Processing Record 41 of the Set 2 | belomorsk
# Processing Record 42 of the Set 2 | sisimiut
# City not found. Skipping...
# Processing Record 43 of the Set 2 | buqayq
# City not found. Skipping...
# Processing Record 44 of the Set 2 | kavieng
# Processing Record 45 of the Set 2 | luena
# Processing Record 46 of the Set 2 | narsaq
# City not found. Skipping...
# Processing Record 47 of the Set 2 | iqaluit
# Processing Record 48 of the Set 2 | khatanga
# Processing Record 49 of the Set 2 | razole
# Processing Record 50 of the Set 2 | hermanus
# Processing Record 1 of the Set 3 | yulara
# Processing Record 2 of the Set 3 | shasta lake
# Processing Record 3 of the Set 3 | chokurdakh
# Processing Record 4 of the Set 3 | preobrazheniye
# Processing Record 5 of the Set 3 | avera
# Processing Record 6 of the Set 3 | yantal
# Processing Record 7 of the Set 3 | matagami
# Processing Record 8 of the Set 3 | dunedin
# Processing Record 9 of the Set 3 | ribeira grande
# Processing Record 10 of the Set 3 | oktyabrskiy
# Processing Record 11 of the Set 3 | thompson
# Processing Record 12 of the Set 3 | hilo
# Processing Record 13 of the Set 3 | bodaybo
# Processing Record 14 of the Set 3 | bagumbayan
# Processing Record 15 of the Set 3 | lubbock
# Processing Record 16 of the Set 3 | derzhavinsk
# City not found. Skipping...
# Processing Record 17 of the Set 3 | pevek
# Processing Record 18 of the Set 3 | nelson bay
# Processing Record 19 of the Set 3 | opuwo
# Processing Record 20 of the Set 3 | chihuahua
# Processing Record 21 of the Set 3 | honningsvag
# Processing Record 22 of the Set 3 | catalina
# Processing Record 23 of the Set 3 | saint-philippe
# Processing Record 24 of the Set 3 | leningradskiy
# Processing Record 25 of the Set 3 | sorvag
# City not found. Skipping...
# Processing Record 26 of the Set 3 | tahta
# Processing Record 27 of the Set 3 | belushya guba
# Processing Record 28 of the Set 3 | sao filipe
# Processing Record 29 of the Set 3 | zlobin
# Processing Record 30 of the Set 3 | krasnoselkup
# Processing Record 31 of the Set 3 | butaritari
# City not found. Skipping...
# Processing Record 32 of the Set 3 | yaan
# Processing Record 33 of the Set 3 | tasiilaq
# City not found. Skipping...
# Processing Record 34 of the Set 3 | buta
# Processing Record 35 of the Set 3 | kununurra
# Processing Record 36 of the Set 3 | longyearbyen
# Processing Record 37 of the Set 3 | bethel
# Processing Record 38 of the Set 3 | sarlat-la-caneda
# Processing Record 39 of the Set 3 | port-gentil
# Processing Record 40 of the Set 3 | quatre cocos
# Processing Record 41 of the Set 3 | lichuan
# Processing Record 42 of the Set 3 | kodiak
# Processing Record 43 of the Set 3 | hithadhoo
# Processing Record 44 of the Set 3 | svetlogorsk
# Processing Record 45 of the Set 3 | boa vista
# Processing Record 46 of the Set 3 | arlit
# Processing Record 47 of the Set 3 | mexico
# Processing Record 48 of the Set 3 | bluff
# Processing Record 49 of the Set 3 | hobart
# Processing Record 50 of the Set 3 | udachnyy
# Processing Record 1 of the Set 4 | senneterre
# Processing Record 2 of the Set 4 | bajo baudo
# Processing Record 3 of the Set 4 | eltham
# Processing Record 4 of the Set 4 | nivala
# Processing Record 5 of the Set 4 | bud
# Processing Record 6 of the Set 4 | nanortalik
# City not found. Skipping...
# Processing Record 7 of the Set 4 | along
# Processing Record 8 of the Set 4 | hitiaa
# Processing Record 9 of the Set 4 | steinbach
# Processing Record 10 of the Set 4 | ancud
# Processing Record 11 of the Set 4 | tazovskiy
# Processing Record 12 of the Set 4 | mys shmidta
# Processing Record 13 of the Set 4 | mahebourg
# Processing Record 14 of the Set 4 | constitucion
# Processing Record 15 of the Set 4 | kuruman
# Processing Record 16 of the Set 4 | atasu
# City not found. Skipping...
# Processing Record 17 of the Set 4 | san cristobal
# Processing Record 18 of the Set 4 | rezekne
# Processing Record 19 of the Set 4 | kambove
# Processing Record 20 of the Set 4 | mar del plata
# Processing Record 21 of the Set 4 | castro
# Processing Record 22 of the Set 4 | hamilton
# Processing Record 23 of the Set 4 | pangnirtung
# Processing Record 24 of the Set 4 | east london
# Processing Record 25 of the Set 4 | dali
# Processing Record 26 of the Set 4 | carutapera
# Processing Record 27 of the Set 4 | conceicao do araguaia
# Processing Record 28 of the Set 4 | goedereede
# Processing Record 29 of the Set 4 | edea
# Processing Record 30 of the Set 4 | wanning
# Processing Record 31 of the Set 4 | louny
# Processing Record 32 of the Set 4 | floro
# Processing Record 33 of the Set 4 | palabuhanratu
# Processing Record 34 of the Set 4 | dhidhdhoo
# Processing Record 35 of the Set 4 | grand river south east
# Processing Record 36 of the Set 4 | clyde river
# Processing Record 37 of the Set 4 | jacareacanga
# Processing Record 38 of the Set 4 | saskylakh
# Processing Record 39 of the Set 4 | dalbandin
# Processing Record 40 of the Set 4 | sorong
# Processing Record 41 of the Set 4 | fairbanks
# Processing Record 42 of the Set 4 | namie
# Processing Record 43 of the Set 4 | lagoa
# Processing Record 44 of the Set 4 | lumphat
# Processing Record 45 of the Set 4 | vizinga
# Processing Record 46 of the Set 4 | turkmenabat
# Processing Record 47 of the Set 4 | loubomo
# Processing Record 48 of the Set 4 | lappeenranta
# Processing Record 49 of the Set 4 | kholodnyy
# Processing Record 50 of the Set 4 | asau
# City not found. Skipping...
# Processing Record 1 of the Set 5 | malvern
# Processing Record 2 of the Set 5 | kysyl-syr
# Processing Record 3 of the Set 5 | katobu
# Processing Record 4 of the Set 5 | broome
# Processing Record 5 of the Set 5 | georgetown
# Processing Record 6 of the Set 5 | soyo
# Processing Record 7 of the Set 5 | torbay
# Processing Record 8 of the Set 5 | dzilam gonzalez
# Processing Record 9 of the Set 5 | cherskiy
# Processing Record 10 of the Set 5 | tecoanapa
# Processing Record 11 of the Set 5 | norman wells
# Processing Record 12 of the Set 5 | aswan
# Processing Record 13 of the Set 5 | seoul
# Processing Record 14 of the Set 5 | ajdabiya
# Processing Record 15 of the Set 5 | kavaratti
# Processing Record 16 of the Set 5 | nishihara
# Processing Record 17 of the Set 5 | bathsheba
# Processing Record 18 of the Set 5 | susehri
# Processing Record 19 of the Set 5 | axim
# Processing Record 20 of the Set 5 | meulaboh
# Processing Record 21 of the Set 5 | carmelo
# Processing Record 22 of the Set 5 | sao felix do xingu
# Processing Record 23 of the Set 5 | ketchikan
# Processing Record 24 of the Set 5 | shaunavon
# Processing Record 25 of the Set 5 | polunochnoye
# Processing Record 26 of the Set 5 | bambanglipuro
# Processing Record 27 of the Set 5 | hercules
# Processing Record 28 of the Set 5 | moindou
# Processing Record 29 of the Set 5 | valparaiso
# Processing Record 30 of the Set 5 | anadyr
# Processing Record 31 of the Set 5 | griffith
# Processing Record 32 of the Set 5 | darnah
# Processing Record 33 of the Set 5 | kyaukse
# Processing Record 34 of the Set 5 | calama
# Processing Record 35 of the Set 5 | constitucion
# Processing Record 36 of the Set 5 | santa maria
# Processing Record 37 of the Set 5 | yellowknife
# Processing Record 38 of the Set 5 | huilong
# Processing Record 39 of the Set 5 | grand gaube
# Processing Record 40 of the Set 5 | songjianghe
# Processing Record 41 of the Set 5 | tawau
# Processing Record 42 of the Set 5 | lamar
# Processing Record 43 of the Set 5 | zeya
# Processing Record 44 of the Set 5 | tiksi
# Processing Record 45 of the Set 5 | maniitsoq
# City not found. Skipping...
# Processing Record 46 of the Set 5 | nenjiang
# Processing Record 47 of the Set 5 | nikolskoye
# Processing Record 48 of the Set 5 | nizwa
# Processing Record 49 of the Set 5 | tumannyy
# Processing Record 50 of the Set 5 | barcelos
# Processing Record 1 of the Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of the Set 6 | bima
# Processing Record 3 of the Set 6 | san vicente
# Processing Record 4 of the Set 6 | ngukurr
# Processing Record 5 of the Set 6 | petropavlovsk-kamchatskiy
# Processing Record 6 of the Set 6 | bogovarovo
# Processing Record 7 of the Set 6 | souillac
# Processing Record 8 of the Set 6 | vao
# Processing Record 9 of the Set 6 | cabo san lucas
# Processing Record 10 of the Set 6 | gao
# Processing Record 11 of the Set 6 | ust-kamchatsk
# Processing Record 12 of the Set 6 | pareora
# Processing Record 13 of the Set 6 | kollam
# Processing Record 14 of the Set 6 | saleaula
# City not found. Skipping...
# Processing Record 15 of the Set 6 | almaznyy
# Processing Record 16 of the Set 6 | ola
# Processing Record 17 of the Set 6 | choa saidan shah
# Processing Record 18 of the Set 6 | aden
# Processing Record 19 of the Set 6 | chumikan
# Processing Record 20 of the Set 6 | vardo
# Processing Record 21 of the Set 6 | hay river
# Processing Record 22 of the Set 6 | arica
# Processing Record 23 of the Set 6 | brockville
# Processing Record 24 of the Set 6 | new norfolk
# Processing Record 25 of the Set 6 | sahuaripa
# Processing Record 26 of the Set 6 | point fortin
# Processing Record 27 of the Set 6 | avarua
# Processing Record 28 of the Set 6 | maraba
# Processing Record 29 of the Set 6 | chapais
# Processing Record 30 of the Set 6 | mundo nuevo
# Processing Record 31 of the Set 6 | amderma
# Processing Record 32 of the Set 6 | bartica
# Processing Record 33 of the Set 6 | san remo
# Processing Record 34 of the Set 6 | tabuk
# City not found. Skipping...
# Processing Record 35 of the Set 6 | ruatoria
# Processing Record 36 of the Set 6 | mitu
# Processing Record 37 of the Set 6 | nome
# Processing Record 38 of the Set 6 | muli
# Processing Record 39 of the Set 6 | toamasina
# City not found. Skipping...
# Processing Record 40 of the Set 6 | kamenskoye
# Processing Record 41 of the Set 6 | khandyga
# Processing Record 42 of the Set 6 | yanan
# Processing Record 43 of the Set 6 | yefira
# City not found. Skipping...
# Processing Record 44 of the Set 6 | kahului
# Processing Record 45 of the Set 6 | barentsburg
# Processing Record 46 of the Set 6 | ostrovnoy
# Processing Record 47 of the Set 6 | hernani
# Processing Record 48 of the Set 6 | mazatan
# Processing Record 49 of the Set 6 | jalu
# Processing Record 50 of the Set 6 | necochea
# Processing Record 1 of the Set 7 | spolaita
# City not found. Skipping...
# Processing Record 2 of the Set 7 | faanui
# Processing Record 3 of the Set 7 | esso
# Processing Record 4 of the Set 7 | bahia de caraquez
# Processing Record 5 of the Set 7 | bundaberg
# Processing Record 6 of the Set 7 | ilulissat
# City not found. Skipping...
# Processing Record 7 of the Set 7 | shenjiamen
# Processing Record 8 of the Set 7 | praia da vitoria
# Processing Record 9 of the Set 7 | olinda
# Processing Record 10 of the Set 7 | ixtapa
# Processing Record 11 of the Set 7 | purpe
# Processing Record 12 of the Set 7 | central point
# Processing Record 13 of the Set 7 | hihifo
# Processing Record 14 of the Set 7 | richards bay
# Processing Record 15 of the Set 7 | whitehorse
# Processing Record 16 of the Set 7 | riyadh
# City not found. Skipping...
# Processing Record 17 of the Set 7 | kutum
# Processing Record 18 of the Set 7 | havre-saint-pierre
# Processing Record 19 of the Set 7 | aklavik
# Processing Record 20 of the Set 7 | huaihua
# Processing Record 21 of the Set 7 | mulege
# Processing Record 22 of the Set 7 | saint george
# Processing Record 23 of the Set 7 | kudahuvadhoo
# Processing Record 24 of the Set 7 | cervo
# Processing Record 25 of the Set 7 | vostok
# Processing Record 26 of the Set 7 | saldanha
# Processing Record 27 of the Set 7 | mut
# Processing Record 28 of the Set 7 | henties bay
# Processing Record 29 of the Set 7 | hofn
# Processing Record 30 of the Set 7 | qui nhon
# Processing Record 31 of the Set 7 | bacolod
# Processing Record 32 of the Set 7 | burla
# Processing Record 33 of the Set 7 | provideniya
# Processing Record 34 of the Set 7 | muhammadabad
# Processing Record 35 of the Set 7 | nabire
# Processing Record 36 of the Set 7 | craig
# Processing Record 37 of the Set 7 | mikuni
# Processing Record 38 of the Set 7 | bulawayo
# Processing Record 39 of the Set 7 | mecca
# City not found. Skipping...
# Processing Record 40 of the Set 7 | morant bay
# Processing Record 41 of the Set 7 | san pedro del parana
# Processing Record 42 of the Set 7 | fort smith
# Processing Record 43 of the Set 7 | makokou
# Processing Record 44 of the Set 7 | nicolas bravo
# Processing Record 45 of the Set 7 | harper
# Processing Record 46 of the Set 7 | mokhotlong
# Processing Record 47 of the Set 7 | bilibino
# Processing Record 48 of the Set 7 | juba
# Processing Record 49 of the Set 7 | robe
# Processing Record 50 of the Set 7 | johvi
# Processing Record 1 of the Set 8 | teguldet
# Processing Record 2 of the Set 8 | brae
# Processing Record 3 of the Set 8 | karratha
# Processing Record 4 of the Set 8 | kidal
# Processing Record 5 of the Set 8 | saint-augustin
# Processing Record 6 of the Set 8 | tumarbong
# Processing Record 7 of the Set 8 | ibra
# Processing Record 8 of the Set 8 | bolshoy tsaryn
# Processing Record 9 of the Set 8 | rusape
# Processing Record 10 of the Set 8 | the pas
# Processing Record 11 of the Set 8 | neyshabur
# Processing Record 12 of the Set 8 | lata
# Processing Record 13 of the Set 8 | morehead
# Processing Record 14 of the Set 8 | pingliang
# Processing Record 15 of the Set 8 | aksarka
# Processing Record 16 of the Set 8 | komsomolskiy
# Processing Record 17 of the Set 8 | tura
# Processing Record 18 of the Set 8 | melnikovo
# Processing Record 19 of the Set 8 | jaora
# Processing Record 20 of the Set 8 | kashan
# Processing Record 21 of the Set 8 | bengkulu
# Processing Record 22 of the Set 8 | fortuna
# Processing Record 23 of the Set 8 | xiamen
# Processing Record 24 of the Set 8 | great yarmouth
# Processing Record 25 of the Set 8 | turukhansk
# Processing Record 26 of the Set 8 | tawang
# Processing Record 27 of the Set 8 | saint-pierre
# Processing Record 28 of the Set 8 | taldan
# Processing Record 29 of the Set 8 | byron bay
# Processing Record 30 of the Set 8 | lompoc
# Processing Record 31 of the Set 8 | sechura
# Processing Record 32 of the Set 8 | aranda de duero
# Processing Record 33 of the Set 8 | auki
# Processing Record 34 of the Set 8 | esperance
# Processing Record 35 of the Set 8 | davila
# Processing Record 36 of the Set 8 | plettenberg bay
# Processing Record 37 of the Set 8 | camacha
# Processing Record 38 of the Set 8 | tacuarembo
# Processing Record 39 of the Set 8 | waipawa
# Processing Record 40 of the Set 8 | arman
# Processing Record 41 of the Set 8 | itarema
# Processing Record 42 of the Set 8 | hambantota
# Processing Record 43 of the Set 8 | bedford
# Processing Record 44 of the Set 8 | boende
# Processing Record 45 of the Set 8 | oranjestad
# Processing Record 46 of the Set 8 | namibe
# Processing Record 47 of the Set 8 | klyuchi
# Processing Record 48 of the Set 8 | pisco
# Processing Record 49 of the Set 8 | talnakh
# Processing Record 50 of the Set 8 | mikhaylovsk
# Processing Record 1 of the Set 9 | ouallam
# Processing Record 2 of the Set 9 | arti
# Processing Record 3 of the Set 9 | praia
# Processing Record 4 of the Set 9 | north platte
# Processing Record 5 of the Set 9 | yumen
# Processing Record 6 of the Set 9 | muros
# Processing Record 7 of the Set 9 | biak
# Processing Record 8 of the Set 9 | khormuj
# Processing Record 9 of the Set 9 | usinsk
# Processing Record 10 of the Set 9 | beibei
# Processing Record 11 of the Set 9 | san patricio
# Processing Record 12 of the Set 9 | gouyave
# Processing Record 13 of the Set 9 | ekibastuz
# Processing Record 14 of the Set 9 | kalmunai
# Processing Record 15 of the Set 9 | vinh
# Processing Record 16 of the Set 9 | eltville
# Processing Record 17 of the Set 9 | patan
# Processing Record 18 of the Set 9 | cairns
# Processing Record 19 of the Set 9 | flinders
# Processing Record 20 of the Set 9 | chabahar
# Processing Record 21 of the Set 9 | viligili
# Processing Record 22 of the Set 9 | tambovka
# Processing Record 23 of the Set 9 | arvika
# Processing Record 24 of the Set 9 | islamkot
# Processing Record 25 of the Set 9 | eureka
# Processing Record 26 of the Set 9 | atar
# Processing Record 27 of the Set 9 | nyimba
# Processing Record 28 of the Set 9 | pori
# Processing Record 29 of the Set 9 | geraldton
# Processing Record 30 of the Set 9 | taksimo
# Processing Record 31 of the Set 9 | roald
# Processing Record 32 of the Set 9 | bolungarvik
# Processing Record 33 of the Set 9 | lavrentiya
# Processing Record 34 of the Set 9 | vila
# Processing Record 35 of the Set 9 | vilhena
# Processing Record 36 of the Set 9 | aitape
# Processing Record 37 of the Set 9 | buala
# Processing Record 38 of the Set 9 | ahipara
# Processing Record 39 of the Set 9 | kautokeino
# Processing Record 40 of the Set 9 | omboue
# Processing Record 41 of the Set 9 | dicabisagan
# Processing Record 42 of the Set 9 | vila velha
# Processing Record 43 of the Set 9 | cassia
# Processing Record 44 of the Set 9 | morgan city
# Processing Record 45 of the Set 9 | hays
# Processing Record 46 of the Set 9 | vila franca do campo
# Processing Record 47 of the Set 9 | tuni
# Processing Record 48 of the Set 9 | kiunga
# Processing Record 49 of the Set 9 | belmonte
# Processing Record 50 of the Set 9 | toliary
# City not found. Skipping...
# Processing Record 1 of the Set 10 | kangaatsiaq
# Processing Record 2 of the Set 10 | haibowan
# Processing Record 3 of the Set 10 | puerto carreno
# Processing Record 4 of the Set 10 | great bend
# Processing Record 5 of the Set 10 | te anau
# Processing Record 6 of the Set 10 | puerto del rosario
# Processing Record 7 of the Set 10 | lakes entrance
# Processing Record 8 of the Set 10 | green valley
# Processing Record 9 of the Set 10 | benguela
# Processing Record 10 of the Set 10 | port hedland
# Processing Record 11 of the Set 10 | payo
# Processing Record 12 of the Set 10 | cidreira
# Processing Record 13 of the Set 10 | hirara
# Processing Record 14 of the Set 10 | reading
# Processing Record 15 of the Set 10 | fort nelson
# Processing Record 16 of the Set 10 | sabzevar
# Processing Record 17 of the Set 10 | chegdomyn
# Processing Record 18 of the Set 10 | altus
# Processing Record 19 of the Set 10 | slave lake
# Processing Record 20 of the Set 10 | nuuk
# Processing Record 21 of the Set 10 | pereyaslovskaya
# Processing Record 22 of the Set 10 | vilyuysk
# Processing Record 23 of the Set 10 | yilan
# Processing Record 24 of the Set 10 | baykit
# Processing Record 25 of the Set 10 | nemuro
# Processing Record 26 of the Set 10 | hearst
# Processing Record 27 of the Set 10 | bara
# Processing Record 28 of the Set 10 | okato
# Processing Record 29 of the Set 10 | berlevag
# Processing Record 30 of the Set 10 | mangrol
# Processing Record 31 of the Set 10 | rocha
# Processing Record 32 of the Set 10 | babanusah
# Processing Record 33 of the Set 10 | changde
# Processing Record 34 of the Set 10 | dapdap
# Processing Record 35 of the Set 10 | tuatapere
# Processing Record 36 of the Set 10 | san quintin
# Processing Record 37 of the Set 10 | samusu
# City not found. Skipping...
# Processing Record 38 of the Set 10 | porosozero
# Processing Record 39 of the Set 10 | ostersund
# Processing Record 40 of the Set 10 | celestun
# Processing Record 41 of the Set 10 | manica
# Processing Record 42 of the Set 10 | nizhniy baskunchak
# Processing Record 43 of the Set 10 | biu
# Processing Record 44 of the Set 10 | apac
# Processing Record 45 of the Set 10 | iralaya
# Processing Record 46 of the Set 10 | pedernales
# Processing Record 47 of the Set 10 | codrington
# Processing Record 48 of the Set 10 | dingle
# Processing Record 49 of the Set 10 | naftah
# City not found. Skipping...
# Processing Record 50 of the Set 10 | merauke
# Processing Record 1 of the Set 11 | chunskiy
# Processing Record 2 of the Set 11 | los llanos de aridane
# Processing Record 3 of the Set 11 | bac lieu
# Processing Record 4 of the Set 11 | palmerston
# Processing Record 5 of the Set 11 | lewistown
# Processing Record 6 of the Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 7 of the Set 11 | san jose
# Processing Record 8 of the Set 11 | cooma
# Processing Record 9 of the Set 11 | mitchell
# Processing Record 10 of the Set 11 | matam
# Processing Record 11 of the Set 11 | storslett
# Processing Record 12 of the Set 11 | bull savanna
# Processing Record 13 of the Set 11 | saravan
# Processing Record 14 of the Set 11 | mungeli
# Processing Record 15 of the Set 11 | bekhtery
# Processing Record 16 of the Set 11 | bad freienwalde
# Processing Record 17 of the Set 11 | corinto
# Processing Record 18 of the Set 11 | porbandar
# Processing Record 19 of the Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 20 of the Set 11 | elbrus
# Processing Record 21 of the Set 11 | port shepstone
# Processing Record 22 of the Set 11 | ossora
# Processing Record 23 of the Set 11 | kilindoni
# Processing Record 24 of the Set 11 | salinopolis
# Processing Record 25 of the Set 11 | bandarbeyla
# Processing Record 26 of the Set 11 | camana
# Processing Record 27 of the Set 11 | caraquet
# Processing Record 28 of the Set 11 | lumberton
# Processing Record 29 of the Set 11 | pampa
# Processing Record 30 of the Set 11 | woodward
# Processing Record 31 of the Set 11 | kantunilkin
# Processing Record 32 of the Set 11 | kuche
# Processing Record 33 of the Set 11 | kampar
# Processing Record 34 of the Set 11 | poum
# Processing Record 35 of the Set 11 | barra do garcas
# Processing Record 36 of the Set 11 | guerrero negro
# Processing Record 37 of the Set 11 | sabang
# Processing Record 38 of the Set 11 | hebertville
# Processing Record 39 of the Set 11 | mokhsogollokh
# Processing Record 40 of the Set 11 | chitral
# Processing Record 41 of the Set 11 | imeni poliny osipenko
# Processing Record 42 of the Set 11 | karmala
# Processing Record 43 of the Set 11 | ginir
# Processing Record 44 of the Set 11 | kalabo
# Processing Record 45 of the Set 11 | hefei
# Processing Record 46 of the Set 11 | kedrovyy
# Processing Record 47 of the Set 11 | moss point
# Processing Record 48 of the Set 11 | honiara
# Processing Record 49 of the Set 11 | mogadishu
# Processing Record 50 of the Set 11 | bantogon
# Processing Record 1 of the Set 12 | oxbow
# Processing Record 2 of the Set 12 | tondod
# Processing Record 3 of the Set 12 | kudowa-zdroj
# Processing Record 4 of the Set 12 | les cayes
# Processing Record 5 of the Set 12 | luanda
# Processing Record 6 of the Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 7 of the Set 12 | college
# Processing Record 8 of the Set 12 | houma
# Processing Record 9 of the Set 12 | xining
# Processing Record 10 of the Set 12 | yerbogachen
# Processing Record 11 of the Set 12 | paraiso
# Processing Record 12 of the Set 12 | goure
# Processing Record 13 of the Set 12 | cap malheureux
# Processing Record 14 of the Set 12 | puqi
# Processing Record 15 of the Set 12 | fukue
# Processing Record 16 of the Set 12 | bhimunipatnam
# Processing Record 17 of the Set 12 | sebinkarahisar
# Processing Record 18 of the Set 12 | puerto madero
# Processing Record 19 of the Set 12 | koraput
# Processing Record 20 of the Set 12 | sungaipenuh
# Processing Record 21 of the Set 12 | umm lajj
# Processing Record 22 of the Set 12 | dakoro
# Processing Record 23 of the Set 12 | talcahuano
# Processing Record 24 of the Set 12 | tantoyuca
# Processing Record 25 of the Set 12 | saint-francois
# Processing Record 26 of the Set 12 | guinguineo
# Processing Record 27 of the Set 12 | gweta
# City not found. Skipping...
# Processing Record 28 of the Set 12 | kloulklubed
# Processing Record 29 of the Set 12 | kaitangata
# Processing Record 30 of the Set 12 | ghanzi
# City not found. Skipping...
# Processing Record 31 of the Set 12 | kirksville
# Processing Record 32 of the Set 12 | goshen
# Processing Record 33 of the Set 12 | weligama
# Processing Record 34 of the Set 12 | half moon bay
# Processing Record 35 of the Set 12 | hunza
# Processing Record 36 of the Set 12 | walvis bay
# Processing Record 37 of the Set 12 | bielsk podlaski
# Processing Record 38 of the Set 12 | xalpatlahuac
# Processing Record 39 of the Set 12 | samana
# Processing Record 40 of the Set 12 | tommot
# Processing Record 41 of the Set 12 | huarmey
# Processing Record 42 of the Set 12 | wheatley
# Processing Record 43 of the Set 12 | daura
# Processing Record 44 of the Set 12 | paratebueno
# Processing Record 45 of the Set 12 | komsomolskoye
# Processing Record 46 of the Set 12 | sao jose da coroa grande
# Processing Record 47 of the Set 12 | coquimbo
# Processing Record 48 of the Set 12 | isfana
# Processing Record 49 of the Set 12 | maputo
# Processing Record 50 of the Set 12 | cary
# Processing Record 1 of the Set 13 | gucheng
# Processing Record 2 of the Set 13 | jinan
# Processing Record 3 of the Set 13 | rungata
# City not found. Skipping...
# Processing Record 4 of the Set 13 | manhush
# Processing Record 5 of the Set 13 | natal
# Processing Record 6 of the Set 13 | karwar
# Processing Record 7 of the Set 13 | taltal
# Processing Record 8 of the Set 13 | smolenka
# Processing Record 9 of the Set 13 | emba
# Processing Record 10 of the Set 13 | edson
# Processing Record 11 of the Set 13 | labuhan
# Processing Record 12 of the Set 13 | saint marys
# Processing Record 13 of the Set 13 | xihua
# Processing Record 14 of the Set 13 | kruglolesskoye
# Processing Record 15 of the Set 13 | hokitika
# Processing Record 16 of the Set 13 | marzuq
# Processing Record 17 of the Set 13 | nadvoitsy
# Processing Record 18 of the Set 13 | beloha
# City not found. Skipping...
# Processing Record 19 of the Set 13 | pervomayskoye
# Processing Record 20 of the Set 13 | najran
# Processing Record 21 of the Set 13 | maine-soroa
# Processing Record 22 of the Set 13 | quelimane
# Processing Record 23 of the Set 13 | nouadhibou
# Processing Record 24 of the Set 13 | palana
# Processing Record 25 of the Set 13 | neiafu
# Processing Record 26 of the Set 13 | srandakan
# Processing Record 27 of the Set 13 | nalut
# Processing Record 28 of the Set 13 | shimoda
# Processing Record 29 of the Set 13 | mount isa
# Processing Record 30 of the Set 13 | guangzhou
# Processing Record 31 of the Set 13 | udayagiri
# Processing Record 32 of the Set 13 | hobyo
# Processing Record 33 of the Set 13 | stornoway
# Processing Record 34 of the Set 13 | kawalu
# Processing Record 35 of the Set 13 | saint-pierre
# Processing Record 36 of the Set 13 | anito
# Processing Record 37 of the Set 13 | palmer
# Processing Record 38 of the Set 13 | skalistyy
# Processing Record 39 of the Set 13 | caravelas
# Processing Record 40 of the Set 13 | karamea
# Processing Record 41 of the Set 13 | alofi
# Processing Record 42 of the Set 13 | betioky
# City not found. Skipping...
# Processing Record 43 of the Set 13 | toila
# Processing Record 44 of the Set 13 | klaksvik
# Processing Record 45 of the Set 13 | mbandaka
# Processing Record 46 of the Set 13 | saint-louis
# Processing Record 47 of the Set 13 | lorengau
# Processing Record 48 of the Set 13 | new gloucester
# Processing Record 49 of the Set 13 | kupang
# Processing Record 50 of the Set 13 | chaoyang
# Processing Record 1 of the Set 14 | voh
# Processing Record 2 of the Set 14 | baillif
# Processing Record 3 of the Set 14 | taburi
# Processing Record 4 of the Set 14 | tinskoy
# Processing Record 5 of the Set 14 | fallon
# Processing Record 6 of the Set 14 | sibolga
# Processing Record 7 of the Set 14 | conceicao da barra
# Processing Record 8 of the Set 14 | takahashi
# Processing Record 9 of the Set 14 | margate
# Processing Record 10 of the Set 14 | carballo
# Processing Record 11 of the Set 14 | mayumba
# Processing Record 12 of the Set 14 | batemans bay
# Processing Record 13 of the Set 14 | the valley
# Processing Record 14 of the Set 14 | tupik
# Processing Record 15 of the Set 14 | aksu
# Processing Record 16 of the Set 14 | rudbar
# Processing Record 17 of the Set 14 | sept-iles
# Processing Record 18 of the Set 14 | amahai
# Processing Record 19 of the Set 14 | lebork
# Processing Record 20 of the Set 14 | halifax
# Processing Record 21 of the Set 14 | soligalich
# Processing Record 22 of the Set 14 | sinnamary
# Processing Record 23 of the Set 14 | coihaique
# Processing Record 24 of the Set 14 | tawkar
# Processing Record 25 of the Set 14 | luoyang
# Processing Record 26 of the Set 14 | praxedis guerrero
# Processing Record 27 of the Set 14 | kulhudhuffushi
# Processing Record 28 of the Set 14 | ulladulla
# Processing Record 29 of the Set 14 | kemijarvi
# Processing Record 30 of the Set 14 | bonavista
# Processing Record 31 of the Set 14 | ardakan
# Processing Record 32 of the Set 14 | karaul
# Processing Record 33 of the Set 14 | korla
# Processing Record 34 of the Set 14 | togur
# Processing Record 35 of the Set 14 | tucupita
# Processing Record 36 of the Set 14 | fosforitnyy
# Processing Record 37 of the Set 14 | pandan
# Processing Record 38 of the Set 14 | candawaga
# Processing Record 39 of the Set 14 | medeiros neto
# Processing Record 40 of the Set 14 | nosy varika
# City not found. Skipping...
# Processing Record 41 of the Set 14 | espanola
# Processing Record 42 of the Set 14 | le lorrain
# Processing Record 43 of the Set 14 | luganville
# Processing Record 44 of the Set 14 | guna
# Processing Record 45 of the Set 14 | mareeba
# Processing Record 46 of the Set 14 | faya
# Processing Record 47 of the Set 14 | nioro
# Processing Record 48 of the Set 14 | havelock
# Processing Record 49 of the Set 14 | road town
# Processing Record 50 of the Set 14 | acajutla
# Processing Record 1 of the Set 15 | port blair
# Processing Record 2 of the Set 15 | doha
# Processing Record 3 of the Set 15 | gunjur
# Processing Record 4 of the Set 15 | shangrao
# Processing Record 5 of the Set 15 | binzhou
# Processing Record 6 of the Set 15 | dongkan
# Processing Record 7 of the Set 15 | acu
# Processing Record 8 of the Set 15 | port hawkesbury
# Processing Record 9 of the Set 15 | koubia
# Processing Record 10 of the Set 15 | ustye
# Processing Record 11 of the Set 15 | curaca
# Processing Record 12 of the Set 15 | kyzyl-suu
# Processing Record 13 of the Set 15 | khor
# Processing Record 14 of the Set 15 | martil
# Processing Record 15 of the Set 15 | erdemli
# Processing Record 16 of the Set 15 | kisesa
# Processing Record 17 of the Set 15 | jardim
# Processing Record 18 of the Set 15 | belyy yar
# Processing Record 19 of the Set 15 | riva
# Processing Record 20 of the Set 15 | novobiryusinskiy
# Processing Record 21 of the Set 15 | tessaoua
# Processing Record 22 of the Set 15 | lucapa
# Processing Record 23 of the Set 15 | mumford
# Processing Record 24 of the Set 15 | paris
# Processing Record 25 of the Set 15 | abu dhabi
# Processing Record 26 of the Set 15 | cabras
# Processing Record 27 of the Set 15 | flin flon
# Processing Record 28 of the Set 15 | tomakomai
# Processing Record 29 of the Set 15 | vanimo
# Processing Record 30 of the Set 15 | fare
# Processing Record 31 of the Set 15 | bani
# Processing Record 32 of the Set 15 | fuerte olimpo
# Processing Record 33 of the Set 15 | bilma
# Processing Record 34 of the Set 15 | segezha
# Processing Record 35 of the Set 15 | evensk
# Processing Record 36 of the Set 15 | arinis
# Processing Record 37 of the Set 15 | nacala
# Processing Record 38 of the Set 15 | zhezkazgan
# Processing Record 39 of the Set 15 | haines junction
# Processing Record 40 of the Set 15 | khujand
# Processing Record 41 of the Set 15 | carahue
# Processing Record 42 of the Set 15 | kirkcudbright
# Processing Record 43 of the Set 15 | lensk
# Processing Record 44 of the Set 15 | williams lake
# Processing Record 45 of the Set 15 | korocha
# Processing Record 46 of the Set 15 | louisbourg
# Processing Record 47 of the Set 15 | bonfim
# Processing Record 48 of the Set 15 | hall
# Processing Record 49 of the Set 15 | roros
# Processing Record 50 of the Set 15 | prabumulih
# Processing Record 1 of the Set 16 | qasigiannguit
# Processing Record 2 of the Set 16 | yar-sale
# Processing Record 3 of the Set 16 | upata
# Processing Record 4 of the Set 16 | srednekolymsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 712

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#                 City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0            Husavik      IS  66.04  -17.34     42.80        87          75
# 1          Inhambane      MZ -23.86   35.38     63.82        71          72
# 2  Sao Joao Da Barra      BR -21.64  -41.05     71.58        86           0
# 3            Rikitea      PF -23.12 -134.97     70.09        84           4
# 4    Arraial Do Cabo      BR -21.64  -41.05     71.58        86           0
#
#    Wind Speed Current Description
# 0       10.29       broken clouds
# 1        7.85       broken clouds
# 2        8.90           clear sky
# 3       17.96           clear sky
# 4        8.90           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")

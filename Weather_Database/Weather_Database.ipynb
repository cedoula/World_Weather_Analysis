# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 769

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | qaanaaq
# Processing Record 2 of the Set 1 | kaitangata
# Processing Record 3 of the Set 1 | tuktoyaktuk
# Processing Record 4 of the Set 1 | melbu
# Processing Record 5 of the Set 1 | kapaa
# Processing Record 6 of the Set 1 | atuona
# Processing Record 7 of the Set 1 | te anau
# Processing Record 8 of the Set 1 | ambon
# Processing Record 9 of the Set 1 | davila
# Processing Record 10 of the Set 1 | victoria
# Processing Record 11 of the Set 1 | rikitea
# Processing Record 12 of the Set 1 | lolua
# City not found. Skipping...
# Processing Record 13 of the Set 1 | mwene-ditu
# Processing Record 14 of the Set 1 | mataura
# Processing Record 15 of the Set 1 | tiksi
# Processing Record 16 of the Set 1 | thompson
# Processing Record 17 of the Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of the Set 1 | sri aman
# Processing Record 19 of the Set 1 | kaeo
# Processing Record 20 of the Set 1 | birao
# Processing Record 21 of the Set 1 | zambezi
# Processing Record 22 of the Set 1 | nouakchott
# Processing Record 23 of the Set 1 | kalabo
# Processing Record 24 of the Set 1 | poum
# Processing Record 25 of the Set 1 | hobart
# Processing Record 26 of the Set 1 | cherskiy
# Processing Record 27 of the Set 1 | mahebourg
# Processing Record 28 of the Set 1 | abu dhabi
# Processing Record 29 of the Set 1 | dikson
# Processing Record 30 of the Set 1 | ust-nera
# Processing Record 31 of the Set 1 | orzhytsya
# Processing Record 32 of the Set 1 | santa cruz
# Processing Record 33 of the Set 1 | litoral del san juan
# City not found. Skipping...
# Processing Record 34 of the Set 1 | east london
# Processing Record 35 of the Set 1 | dingle
# Processing Record 36 of the Set 1 | champerico
# Processing Record 37 of the Set 1 | walvis bay
# Processing Record 38 of the Set 1 | grand river south east
# Processing Record 39 of the Set 1 | aldan
# Processing Record 40 of the Set 1 | saint-philippe
# Processing Record 41 of the Set 1 | khatanga
# Processing Record 42 of the Set 1 | utinga
# Processing Record 43 of the Set 1 | busselton
# Processing Record 44 of the Set 1 | high level
# Processing Record 45 of the Set 1 | casas grandes
# Processing Record 46 of the Set 1 | tuatapere
# Processing Record 47 of the Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 48 of the Set 1 | port alfred
# Processing Record 49 of the Set 1 | sistranda
# Processing Record 50 of the Set 1 | aripuana
# Processing Record 1 of the Set 2 | ushuaia
# Processing Record 2 of the Set 2 | cabinda
# Processing Record 3 of the Set 2 | vardo
# Processing Record 4 of the Set 2 | labuhan
# Processing Record 5 of the Set 2 | saldanha
# Processing Record 6 of the Set 2 | araruna
# Processing Record 7 of the Set 2 | rondonopolis
# Processing Record 8 of the Set 2 | barrow
# Processing Record 9 of the Set 2 | vaini
# Processing Record 10 of the Set 2 | omboue
# Processing Record 11 of the Set 2 | chuy
# Processing Record 12 of the Set 2 | lata
# Processing Record 13 of the Set 2 | ribeira grande
# Processing Record 14 of the Set 2 | palmer
# Processing Record 15 of the Set 2 | bluff
# Processing Record 16 of the Set 2 | hermanus
# Processing Record 17 of the Set 2 | sinjar
# Processing Record 18 of the Set 2 | new norfolk
# Processing Record 19 of the Set 2 | bredasdorp
# Processing Record 20 of the Set 2 | shenzhen
# Processing Record 21 of the Set 2 | mrirt
# City not found. Skipping...
# Processing Record 22 of the Set 2 | yar-sale
# Processing Record 23 of the Set 2 | airai
# Processing Record 24 of the Set 2 | hilo
# Processing Record 25 of the Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 26 of the Set 2 | sola
# Processing Record 27 of the Set 2 | cape town
# Processing Record 28 of the Set 2 | esperance
# Processing Record 29 of the Set 2 | puerto ayora
# Processing Record 30 of the Set 2 | marcona
# City not found. Skipping...
# Processing Record 31 of the Set 2 | pietersburg
# Processing Record 32 of the Set 2 | heishan
# Processing Record 33 of the Set 2 | castro
# Processing Record 34 of the Set 2 | avesta
# Processing Record 35 of the Set 2 | abrau-dyurso
# Processing Record 36 of the Set 2 | pokaran
# Processing Record 37 of the Set 2 | ngunguru
# Processing Record 38 of the Set 2 | lompoc
# Processing Record 39 of the Set 2 | lumeje
# Processing Record 40 of the Set 2 | new bern
# Processing Record 41 of the Set 2 | portland
# Processing Record 42 of the Set 2 | caravelas
# Processing Record 43 of the Set 2 | jamestown
# Processing Record 44 of the Set 2 | carnarvon
# Processing Record 45 of the Set 2 | albany
# Processing Record 46 of the Set 2 | broome
# Processing Record 47 of the Set 2 | itarema
# Processing Record 48 of the Set 2 | tairua
# Processing Record 49 of the Set 2 | sisimiut
# Processing Record 50 of the Set 2 | hailey
# Processing Record 1 of the Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of the Set 3 | fort nelson
# Processing Record 3 of the Set 3 | sangamner
# Processing Record 4 of the Set 3 | seddon
# Processing Record 5 of the Set 3 | bambous virieux
# Processing Record 6 of the Set 3 | vestmanna
# Processing Record 7 of the Set 3 | mayumba
# Processing Record 8 of the Set 3 | tasiilaq
# Processing Record 9 of the Set 3 | tumannyy
# Processing Record 10 of the Set 3 | pacific grove
# Processing Record 11 of the Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 12 of the Set 3 | leningradskiy
# Processing Record 13 of the Set 3 | sabha
# Processing Record 14 of the Set 3 | texarkana
# Processing Record 15 of the Set 3 | terpsithea
# Processing Record 16 of the Set 3 | kilindoni
# Processing Record 17 of the Set 3 | punta arenas
# Processing Record 18 of the Set 3 | ossora
# Processing Record 19 of the Set 3 | upernavik
# Processing Record 20 of the Set 3 | constitucion
# Processing Record 21 of the Set 3 | gornozavodsk
# Processing Record 22 of the Set 3 | peruibe
# Processing Record 23 of the Set 3 | burica
# City not found. Skipping...
# Processing Record 24 of the Set 3 | voskresenskoye
# Processing Record 25 of the Set 3 | lai
# Processing Record 26 of the Set 3 | maksatikha
# Processing Record 27 of the Set 3 | comodoro rivadavia
# Processing Record 28 of the Set 3 | florence
# Processing Record 29 of the Set 3 | saint george
# Processing Record 30 of the Set 3 | butaritari
# City not found. Skipping...
# Processing Record 31 of the Set 3 | illoqqortoormiut
# Processing Record 32 of the Set 3 | kodiak
# Processing Record 33 of the Set 3 | sakakah
# Processing Record 34 of the Set 3 | kyra
# Processing Record 35 of the Set 3 | san cristobal
# Processing Record 36 of the Set 3 | farafangana
# City not found. Skipping...
# Processing Record 37 of the Set 3 | lavrentiya
# Processing Record 38 of the Set 3 | faratsiho
# City not found. Skipping...
# Processing Record 39 of the Set 3 | paramirim
# Processing Record 40 of the Set 3 | almaznyy
# Processing Record 41 of the Set 3 | ostersund
# Processing Record 42 of the Set 3 | bafq
# Processing Record 43 of the Set 3 | saint-augustin
# Processing Record 44 of the Set 3 | nguiu
# Processing Record 45 of the Set 3 | tigil
# Processing Record 46 of the Set 3 | takhtamygda
# Processing Record 47 of the Set 3 | gilgit
# Processing Record 48 of the Set 3 | toliary
# City not found. Skipping...
# Processing Record 49 of the Set 3 | provideniya
# Processing Record 50 of the Set 3 | afsin
# Processing Record 1 of the Set 4 | longyearbyen
# Processing Record 2 of the Set 4 | bentiu
# Processing Record 3 of the Set 4 | gravdal
# Processing Record 4 of the Set 4 | karaman
# Processing Record 5 of the Set 4 | uglich
# Processing Record 6 of the Set 4 | paamiut
# Processing Record 7 of the Set 4 | charlestown
# Processing Record 8 of the Set 4 | amderma
# Processing Record 9 of the Set 4 | bairiki
# City not found. Skipping...
# Processing Record 10 of the Set 4 | kavieng
# Processing Record 11 of the Set 4 | huilong
# Processing Record 12 of the Set 4 | feni
# Processing Record 13 of the Set 4 | majene
# Processing Record 14 of the Set 4 | geraldton
# Processing Record 15 of the Set 4 | kirn
# Processing Record 16 of the Set 4 | tucupita
# Processing Record 17 of the Set 4 | bethel
# Processing Record 18 of the Set 4 | tarko-sale
# Processing Record 19 of the Set 4 | wanning
# Processing Record 20 of the Set 4 | biltine
# Processing Record 21 of the Set 4 | cruz alta
# Processing Record 22 of the Set 4 | touros
# Processing Record 23 of the Set 4 | alofi
# Processing Record 24 of the Set 4 | barentsburg
# Processing Record 25 of the Set 4 | abakaliki
# Processing Record 26 of the Set 4 | ruatoria
# Processing Record 27 of the Set 4 | batagay
# Processing Record 28 of the Set 4 | pochutla
# Processing Record 29 of the Set 4 | luba
# Processing Record 30 of the Set 4 | havelock
# Processing Record 31 of the Set 4 | kayes
# Processing Record 32 of the Set 4 | nacala
# Processing Record 33 of the Set 4 | guerrero negro
# Processing Record 34 of the Set 4 | port elizabeth
# Processing Record 35 of the Set 4 | shakiso
# Processing Record 36 of the Set 4 | kudamatsu
# Processing Record 37 of the Set 4 | beecher
# Processing Record 38 of the Set 4 | bull savanna
# Processing Record 39 of the Set 4 | bury saint edmunds
# City not found. Skipping...
# Processing Record 40 of the Set 4 | puri
# Processing Record 41 of the Set 4 | saint-leu
# Processing Record 42 of the Set 4 | akdepe
# Processing Record 43 of the Set 4 | petropavlovsk-kamchatskiy
# Processing Record 44 of the Set 4 | aktas
# Processing Record 45 of the Set 4 | todos santos
# Processing Record 46 of the Set 4 | samusu
# City not found. Skipping...
# Processing Record 47 of the Set 4 | amga
# Processing Record 48 of the Set 4 | lasa
# Processing Record 49 of the Set 4 | severo-kurilsk
# Processing Record 50 of the Set 4 | chernukha
# Processing Record 1 of the Set 5 | ankpa
# Processing Record 2 of the Set 5 | hirara
# Processing Record 3 of the Set 5 | ko samui
# Processing Record 4 of the Set 5 | vastervik
# Processing Record 5 of the Set 5 | taoudenni
# Processing Record 6 of the Set 5 | sao joao da barra
# Processing Record 7 of the Set 5 | mareeba
# Processing Record 8 of the Set 5 | yellowknife
# Processing Record 9 of the Set 5 | chokurdakh
# Processing Record 10 of the Set 5 | nouadhibou
# Processing Record 11 of the Set 5 | boksitogorsk
# Processing Record 12 of the Set 5 | asau
# City not found. Skipping...
# Processing Record 13 of the Set 5 | souillac
# Processing Record 14 of the Set 5 | aklavik
# Processing Record 15 of the Set 5 | akyab
# Processing Record 16 of the Set 5 | vao
# Processing Record 17 of the Set 5 | maniitsoq
# Processing Record 18 of the Set 5 | muskegon
# Processing Record 19 of the Set 5 | zhigansk
# Processing Record 20 of the Set 5 | lagoa
# Processing Record 21 of the Set 5 | mingaora
# Processing Record 22 of the Set 5 | gayeri
# Processing Record 23 of the Set 5 | cayenne
# Processing Record 24 of the Set 5 | jaisalmer
# Processing Record 25 of the Set 5 | balsas
# Processing Record 26 of the Set 5 | fayaoue
# Processing Record 27 of the Set 5 | husavik
# Processing Record 28 of the Set 5 | axim
# Processing Record 29 of the Set 5 | adre
# Processing Record 30 of the Set 5 | saskylakh
# Processing Record 31 of the Set 5 | ahipara
# Processing Record 32 of the Set 5 | andra
# Processing Record 33 of the Set 5 | general roca
# Processing Record 34 of the Set 5 | avarua
# Processing Record 35 of the Set 5 | luderitz
# Processing Record 36 of the Set 5 | hofn
# Processing Record 37 of the Set 5 | zlobin
# Processing Record 38 of the Set 5 | hasaki
# Processing Record 39 of the Set 5 | kirovohrad
# Processing Record 40 of the Set 5 | tumut
# Processing Record 41 of the Set 5 | kahului
# Processing Record 42 of the Set 5 | serednye vodyane
# Processing Record 43 of the Set 5 | bengkulu
# Processing Record 44 of the Set 5 | sao bento do sul
# Processing Record 45 of the Set 5 | vereya
# Processing Record 46 of the Set 5 | nador
# City not found. Skipping...
# Processing Record 47 of the Set 5 | san patricio
# Processing Record 48 of the Set 5 | waipawa
# Processing Record 49 of the Set 5 | norman wells
# Processing Record 50 of the Set 5 | nizhneyansk
# Processing Record 1 of the Set 6 | karamea
# Processing Record 2 of the Set 6 | lebu
# Processing Record 3 of the Set 6 | emmaus
# Processing Record 4 of the Set 6 | lamu
# Processing Record 5 of the Set 6 | hithadhoo
# Processing Record 6 of the Set 6 | monte alegre
# Processing Record 7 of the Set 6 | clyde river
# Processing Record 8 of the Set 6 | kargasok
# Processing Record 9 of the Set 6 | beringovskiy
# Processing Record 10 of the Set 6 | sinnamary
# Processing Record 11 of the Set 6 | usogorsk
# Processing Record 12 of the Set 6 | kerema
# Processing Record 13 of the Set 6 | mao
# Processing Record 14 of the Set 6 | ponta do sol
# Processing Record 15 of the Set 6 | healdsburg
# Processing Record 16 of the Set 6 | san policarpo
# Processing Record 17 of the Set 6 | hamilton
# Processing Record 18 of the Set 6 | mayo
# Processing Record 19 of the Set 6 | venezuela
# Processing Record 20 of the Set 6 | narsaq
# Processing Record 21 of the Set 6 | yarkovo
# Processing Record 22 of the Set 6 | padilla
# Processing Record 23 of the Set 6 | kirkuk
# Processing Record 24 of the Set 6 | oyama
# Processing Record 25 of the Set 6 | yumen
# Processing Record 26 of the Set 6 | kokopo
# Processing Record 27 of the Set 6 | westport
# Processing Record 28 of the Set 6 | thinadhoo
# Processing Record 29 of the Set 6 | faanui
# Processing Record 30 of the Set 6 | duz
# City not found. Skipping...
# Processing Record 31 of the Set 6 | tutoia
# Processing Record 32 of the Set 6 | torbay
# Processing Record 33 of the Set 6 | banda aceh
# Processing Record 34 of the Set 6 | jabinyanah
# City not found. Skipping...
# Processing Record 35 of the Set 6 | mporokoso
# Processing Record 36 of the Set 6 | arraial do cabo
# Processing Record 37 of the Set 6 | marsh harbour
# Processing Record 38 of the Set 6 | mar del plata
# Processing Record 39 of the Set 6 | inderborskiy
# Processing Record 40 of the Set 6 | necochea
# Processing Record 41 of the Set 6 | panjab
# Processing Record 42 of the Set 6 | dagda
# Processing Record 43 of the Set 6 | georgetown
# Processing Record 44 of the Set 6 | xuddur
# Processing Record 45 of the Set 6 | nikolskoye
# Processing Record 46 of the Set 6 | belushya guba
# Processing Record 47 of the Set 6 | brae
# City not found. Skipping...
# Processing Record 48 of the Set 6 | bossangoa
# Processing Record 49 of the Set 6 | lulea
# Processing Record 50 of the Set 6 | saint-joseph
# Processing Record 1 of the Set 7 | krasnokamensk
# Processing Record 2 of the Set 7 | varhaug
# Processing Record 3 of the Set 7 | jardim
# Processing Record 4 of the Set 7 | shevchenkove
# Processing Record 5 of the Set 7 | paita
# City not found. Skipping...
# Processing Record 6 of the Set 7 | aloleng
# Processing Record 7 of the Set 7 | maiduguri
# Processing Record 8 of the Set 7 | dunedin
# Processing Record 9 of the Set 7 | pevek
# Processing Record 10 of the Set 7 | nemuro
# Processing Record 11 of the Set 7 | lorengau
# Processing Record 12 of the Set 7 | jinchang
# Processing Record 13 of the Set 7 | salalah
# Processing Record 14 of the Set 7 | san ramon
# Processing Record 15 of the Set 7 | yanam
# Processing Record 16 of the Set 7 | vanderhoof
# Processing Record 17 of the Set 7 | kingston
# Processing Record 18 of the Set 7 | sobolevo
# Processing Record 19 of the Set 7 | fortuna
# Processing Record 20 of the Set 7 | tomatlan
# Processing Record 21 of the Set 7 | kenai
# Processing Record 22 of the Set 7 | codrington
# Processing Record 23 of the Set 7 | quatre cocos
# Processing Record 24 of the Set 7 | buchanan
# Processing Record 25 of the Set 7 | clearwater
# Processing Record 26 of the Set 7 | sao miguel do araguaia
# Processing Record 27 of the Set 7 | krasnoselkup
# Processing Record 28 of the Set 7 | villa carlos paz
# Processing Record 29 of the Set 7 | wewak
# Processing Record 30 of the Set 7 | jamestown
# Processing Record 31 of the Set 7 | puerto baquerizo moreno
# Processing Record 32 of the Set 7 | am timan
# Processing Record 33 of the Set 7 | huarmey
# City not found. Skipping...
# Processing Record 34 of the Set 7 | cabo san lucas
# Processing Record 35 of the Set 7 | karaul
# Processing Record 36 of the Set 7 | srednekolymsk
# Processing Record 37 of the Set 7 | ponta do sol
# Processing Record 38 of the Set 7 | bafoulabe
# Processing Record 39 of the Set 7 | matara
# Processing Record 40 of the Set 7 | ishigaki
# Processing Record 41 of the Set 7 | pangnirtung
# Processing Record 42 of the Set 7 | havixbeck
# Processing Record 43 of the Set 7 | greencastle
# Processing Record 44 of the Set 7 | henties bay
# Processing Record 45 of the Set 7 | high prairie
# Processing Record 46 of the Set 7 | maluko
# Processing Record 47 of the Set 7 | mys shmidta
# Processing Record 48 of the Set 7 | lethbridge
# Processing Record 49 of the Set 7 | litovko
# Processing Record 50 of the Set 7 | vila velha
# Processing Record 1 of the Set 8 | hambantota
# Processing Record 2 of the Set 8 | oil city
# Processing Record 3 of the Set 8 | laguna
# Processing Record 4 of the Set 8 | vostok
# Processing Record 5 of the Set 8 | huesca
# Processing Record 6 of the Set 8 | port-gentil
# Processing Record 7 of the Set 8 | krasnyy oktyabr
# Processing Record 8 of the Set 8 | luis correia
# Processing Record 9 of the Set 8 | saleaula
# City not found. Skipping...
# Processing Record 10 of the Set 8 | marienburg
# Processing Record 11 of the Set 8 | nadvoitsy
# Processing Record 12 of the Set 8 | muros
# Processing Record 13 of the Set 8 | mafeteng
# Processing Record 14 of the Set 8 | alice springs
# Processing Record 15 of the Set 8 | roald
# Processing Record 16 of the Set 8 | lexington
# Processing Record 17 of the Set 8 | namibe
# Processing Record 18 of the Set 8 | bazarnyye mataki
# Processing Record 19 of the Set 8 | sinnai
# Processing Record 20 of the Set 8 | jiwani
# Processing Record 21 of the Set 8 | bukachacha
# Processing Record 22 of the Set 8 | juba
# Processing Record 23 of the Set 8 | mocuba
# Processing Record 24 of the Set 8 | katsuura
# Processing Record 25 of the Set 8 | sur
# Processing Record 26 of the Set 8 | imola
# Processing Record 27 of the Set 8 | udachnyy
# Processing Record 28 of the Set 8 | cidreira
# Processing Record 29 of the Set 8 | olinda
# Processing Record 30 of the Set 8 | alugan
# Processing Record 31 of the Set 8 | pingliang
# Processing Record 32 of the Set 8 | miri
# Processing Record 33 of the Set 8 | macklin
# Processing Record 34 of the Set 8 | solwezi
# Processing Record 35 of the Set 8 | attawapiskat
# Processing Record 36 of the Set 8 | feicheng
# Processing Record 37 of the Set 8 | lalomanu
# City not found. Skipping...
# Processing Record 38 of the Set 8 | yarmouth
# Processing Record 39 of the Set 8 | aqtobe
# Processing Record 40 of the Set 8 | aykhal
# Processing Record 41 of the Set 8 | baghdad
# Processing Record 42 of the Set 8 | samarai
# Processing Record 43 of the Set 8 | lashio
# Processing Record 44 of the Set 8 | alexandria
# Processing Record 45 of the Set 8 | gornyy
# Processing Record 46 of the Set 8 | megion
# Processing Record 47 of the Set 8 | atar
# Processing Record 48 of the Set 8 | neuquen
# Processing Record 49 of the Set 8 | lima
# Processing Record 50 of the Set 8 | mezen
# Processing Record 1 of the Set 9 | vikhorevka
# Processing Record 2 of the Set 9 | ponta delgada
# Processing Record 3 of the Set 9 | uwayl
# Processing Record 4 of the Set 9 | pozo colorado
# Processing Record 5 of the Set 9 | los llanos de aridane
# Processing Record 6 of the Set 9 | ahumada
# Processing Record 7 of the Set 9 | fomboni
# Processing Record 8 of the Set 9 | batagay-alyta
# Processing Record 9 of the Set 9 | ancud
# Processing Record 10 of the Set 9 | fujin
# Processing Record 11 of the Set 9 | soyo
# Processing Record 12 of the Set 9 | hervey bay
# Processing Record 13 of the Set 9 | camana
# Processing Record 14 of the Set 9 | skjervoy
# Processing Record 15 of the Set 9 | lincoln
# Processing Record 16 of the Set 9 | san quintin
# Processing Record 17 of the Set 9 | vanimo
# Processing Record 18 of the Set 9 | talaya
# Processing Record 19 of the Set 9 | bahia de caraquez
# Processing Record 20 of the Set 9 | ixtapa
# Processing Record 21 of the Set 9 | sechura
# Processing Record 22 of the Set 9 | north bend
# Processing Record 23 of the Set 9 | vila franca do campo
# Processing Record 24 of the Set 9 | honiara
# Processing Record 25 of the Set 9 | wajir
# Processing Record 26 of the Set 9 | lvov
# Processing Record 27 of the Set 9 | bolobo
# Processing Record 28 of the Set 9 | odweyne
# Processing Record 29 of the Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 30 of the Set 9 | port macquarie
# Processing Record 31 of the Set 9 | la palma
# City not found. Skipping...
# Processing Record 32 of the Set 9 | puerto del rosario
# Processing Record 33 of the Set 9 | gundsomagle
# Processing Record 34 of the Set 9 | sao filipe
# Processing Record 35 of the Set 9 | gillette
# Processing Record 36 of the Set 9 | methoni
# Processing Record 37 of the Set 9 | ulaanbaatar
# Processing Record 38 of the Set 9 | dire
# Processing Record 39 of the Set 9 | kokuy
# Processing Record 40 of the Set 9 | inongo
# Processing Record 41 of the Set 9 | faya
# Processing Record 42 of the Set 9 | palu
# Processing Record 43 of the Set 9 | karratha
# Processing Record 44 of the Set 9 | guatire
# Processing Record 45 of the Set 9 | belfast
# Processing Record 46 of the Set 9 | houma
# Processing Record 47 of the Set 9 | draganesti de vede
# Processing Record 48 of the Set 9 | powell
# Processing Record 49 of the Set 9 | gat
# Processing Record 50 of the Set 9 | sentyabrskiy
# Processing Record 1 of the Set 10 | klaksvik
# Processing Record 2 of the Set 10 | haicheng
# Processing Record 3 of the Set 10 | yerbogachen
# Processing Record 4 of the Set 10 | kuche
# Processing Record 5 of the Set 10 | koslan
# Processing Record 6 of the Set 10 | beyneu
# Processing Record 7 of the Set 10 | san carlos de bariloche
# Processing Record 8 of the Set 10 | kieta
# Processing Record 9 of the Set 10 | progreso
# Processing Record 10 of the Set 10 | viedma
# Processing Record 11 of the Set 10 | fort-shevchenko
# Processing Record 12 of the Set 10 | marawi
# Processing Record 13 of the Set 10 | kambove
# Processing Record 14 of the Set 10 | hovd
# Processing Record 15 of the Set 10 | wexford
# Processing Record 16 of the Set 10 | rungata
# City not found. Skipping...
# Processing Record 17 of the Set 10 | gizo
# Processing Record 18 of the Set 10 | maturin
# Processing Record 19 of the Set 10 | karakol
# Processing Record 20 of the Set 10 | santarem
# Processing Record 21 of the Set 10 | pandamatenga
# Processing Record 22 of the Set 10 | guanhaes
# Processing Record 23 of the Set 10 | haines junction
# Processing Record 24 of the Set 10 | jiuquan
# Processing Record 25 of the Set 10 | natagaima
# Processing Record 26 of the Set 10 | sao felix do xingu
# Processing Record 27 of the Set 10 | la paz
# Processing Record 28 of the Set 10 | homer
# Processing Record 29 of the Set 10 | desnogorsk
# Processing Record 30 of the Set 10 | maxixe
# Processing Record 31 of the Set 10 | mutata
# Processing Record 32 of the Set 10 | tarauaca
# Processing Record 33 of the Set 10 | ituiutaba
# Processing Record 34 of the Set 10 | port lincoln
# Processing Record 35 of the Set 10 | kruisfontein
# Processing Record 36 of the Set 10 | riosucio
# Processing Record 37 of the Set 10 | suao
# City not found. Skipping...
# Processing Record 38 of the Set 10 | shingu
# Processing Record 39 of the Set 10 | evensk
# Processing Record 40 of the Set 10 | guadalupe y calvo
# Processing Record 41 of the Set 10 | saint-francois
# Processing Record 42 of the Set 10 | olafsvik
# Processing Record 43 of the Set 10 | burnie
# Processing Record 44 of the Set 10 | iqaluit
# Processing Record 45 of the Set 10 | liverpool
# Processing Record 46 of the Set 10 | concarneau
# Processing Record 47 of the Set 10 | yuzhno-yeniseyskiy
# Processing Record 48 of the Set 10 | pathein
# Processing Record 49 of the Set 10 | hondo
# Processing Record 50 of the Set 10 | jalu
# Processing Record 1 of the Set 11 | gwanda
# Processing Record 2 of the Set 11 | timra
# Processing Record 3 of the Set 11 | zhangye
# Processing Record 4 of the Set 11 | karamay
# Processing Record 5 of the Set 11 | coihueco
# Processing Record 6 of the Set 11 | anshan
# Processing Record 7 of the Set 11 | hunza
# Processing Record 8 of the Set 11 | hengshui
# Processing Record 9 of the Set 11 | tadine
# Processing Record 10 of the Set 11 | altamont
# Processing Record 11 of the Set 11 | chak jhumra
# Processing Record 12 of the Set 11 | orgun
# Processing Record 13 of the Set 11 | melton
# Processing Record 14 of the Set 11 | shenjiamen
# Processing Record 15 of the Set 11 | saint anthony
# Processing Record 16 of the Set 11 | viligili
# Processing Record 17 of the Set 11 | vila
# Processing Record 18 of the Set 11 | kisangani
# Processing Record 19 of the Set 11 | ambilobe
# Processing Record 20 of the Set 11 | tambul
# Processing Record 21 of the Set 11 | okha
# Processing Record 22 of the Set 11 | ayan
# Processing Record 23 of the Set 11 | tecoanapa
# Processing Record 24 of the Set 11 | buala
# Processing Record 25 of the Set 11 | abay
# Processing Record 26 of the Set 11 | san diego de los banos
# Processing Record 27 of the Set 11 | qaqortoq
# Processing Record 28 of the Set 11 | steamboat springs
# Processing Record 29 of the Set 11 | gushi
# Processing Record 30 of the Set 11 | tromso
# Processing Record 31 of the Set 11 | aleksandrovskiy zavod
# Processing Record 32 of the Set 11 | karkaralinsk
# Processing Record 33 of the Set 11 | manitouwadge
# Processing Record 34 of the Set 11 | grindavik
# Processing Record 35 of the Set 11 | kamiiso
# Processing Record 36 of the Set 11 | mahajanga
# Processing Record 37 of the Set 11 | meulaboh
# Processing Record 38 of the Set 11 | slonim
# Processing Record 39 of the Set 11 | yinchuan
# Processing Record 40 of the Set 11 | asayita
# Processing Record 41 of the Set 11 | johvi
# Processing Record 42 of the Set 11 | kastamonu
# Processing Record 43 of the Set 11 | port hardy
# Processing Record 44 of the Set 11 | egvekinot
# Processing Record 45 of the Set 11 | hobyo
# Processing Record 46 of the Set 11 | buribay
# Processing Record 47 of the Set 11 | luanda
# Processing Record 48 of the Set 11 | ilulissat
# Processing Record 49 of the Set 11 | tsihombe
# Processing Record 50 of the Set 11 | ulcinj
# Processing Record 1 of the Set 12 | bandarbeyla
# Processing Record 2 of the Set 12 | santa maria
# Processing Record 3 of the Set 12 | tasbuget
# Processing Record 4 of the Set 12 | nanortalik
# Processing Record 5 of the Set 12 | korla
# Processing Record 6 of the Set 12 | sofiysk
# Processing Record 7 of the Set 12 | hatton
# Processing Record 8 of the Set 12 | chapadinha
# Processing Record 9 of the Set 12 | saurimo
# Processing Record 10 of the Set 12 | ozinki
# Processing Record 11 of the Set 12 | palabuhanratu
# Processing Record 12 of the Set 12 | mahadday weyne
# Processing Record 13 of the Set 12 | prince rupert
# Processing Record 14 of the Set 12 | moranbah
# Processing Record 15 of the Set 12 | santa barbara
# Processing Record 16 of the Set 12 | meridian
# Processing Record 17 of the Set 12 | desbiens
# Processing Record 18 of the Set 12 | taltal
# Processing Record 19 of the Set 12 | krasnoarmeysk
# Processing Record 20 of the Set 12 | kirakira
# Processing Record 21 of the Set 12 | vuktyl
# Processing Record 22 of the Set 12 | uman
# Processing Record 23 of the Set 12 | sabanalarga
# Processing Record 24 of the Set 12 | vodnyy
# Processing Record 25 of the Set 12 | kot kapura
# Processing Record 26 of the Set 12 | chernyshevskiy
# Processing Record 27 of the Set 12 | rawson
# Processing Record 28 of the Set 12 | nishihara
# Processing Record 29 of the Set 12 | yulara
# Processing Record 30 of the Set 12 | bere
# Processing Record 31 of the Set 12 | parkes
# Processing Record 32 of the Set 12 | port hawkesbury
# Processing Record 33 of the Set 12 | alta floresta
# Processing Record 34 of the Set 12 | yen bai
# Processing Record 35 of the Set 12 | bloemfontein
# Processing Record 36 of the Set 12 | benevides
# Processing Record 37 of the Set 12 | bongandanga
# Processing Record 38 of the Set 12 | kangaatsiaq
# Processing Record 39 of the Set 12 | snyder
# Processing Record 40 of the Set 12 | norrkoping
# Processing Record 41 of the Set 12 | karasburg
# Processing Record 42 of the Set 12 | oranjestad
# Processing Record 43 of the Set 12 | angoram
# Processing Record 44 of the Set 12 | subaytilah
# City not found. Skipping...
# Processing Record 45 of the Set 12 | chauk
# Processing Record 46 of the Set 12 | ngukurr
# Processing Record 47 of the Set 12 | formoso do araguaia
# Processing Record 48 of the Set 12 | anadyr
# Processing Record 49 of the Set 12 | ucluelet
# Processing Record 50 of the Set 12 | gambela
# Processing Record 1 of the Set 13 | howard springs
# Processing Record 2 of the Set 13 | krasnoturansk
# Processing Record 3 of the Set 13 | el alto
# Processing Record 4 of the Set 13 | labuan
# Processing Record 5 of the Set 13 | berlevag
# Processing Record 6 of the Set 13 | college
# Processing Record 7 of the Set 13 | bilibino
# Processing Record 8 of the Set 13 | chazuta
# Processing Record 9 of the Set 13 | manicore
# Processing Record 10 of the Set 13 | parrsboro
# Processing Record 11 of the Set 13 | rocha
# Processing Record 12 of the Set 13 | kpagouda
# City not found. Skipping...
# Processing Record 13 of the Set 13 | borovoy
# Processing Record 14 of the Set 13 | bargal
# Processing Record 15 of the Set 13 | bilma
# Processing Record 16 of the Set 13 | along
# Processing Record 17 of the Set 13 | pisco
# Processing Record 18 of the Set 13 | sitka
# Processing Record 19 of the Set 13 | nome
# Processing Record 20 of the Set 13 | palaiokhora
# Processing Record 21 of the Set 13 | salinas
# Processing Record 22 of the Set 13 | nynashamn
# Processing Record 23 of the Set 13 | charlestown
# Processing Record 24 of the Set 13 | itoman
# Processing Record 25 of the Set 13 | songjianghe
# Processing Record 26 of the Set 13 | coquimbo
# Processing Record 27 of the Set 13 | los chiles
# Processing Record 28 of the Set 13 | vicuna
# Processing Record 29 of the Set 13 | carutapera
# Processing Record 30 of the Set 13 | pangkalanbuun
# Processing Record 31 of the Set 13 | rapid valley
# Processing Record 32 of the Set 13 | moerai
# Processing Record 33 of the Set 13 | palma del rio
# Processing Record 34 of the Set 13 | uryupinsk
# Processing Record 35 of the Set 13 | willowmore
# Processing Record 36 of the Set 13 | eucaliptus
# Processing Record 37 of the Set 13 | mogadishu
# Processing Record 38 of the Set 13 | solsvik
# Processing Record 39 of the Set 13 | coihaique
# Processing Record 40 of the Set 13 | kupang
# Processing Record 41 of the Set 13 | namie
# Processing Record 42 of the Set 13 | oksfjord
# Processing Record 43 of the Set 13 | taguatinga
# Processing Record 44 of the Set 13 | labrea
# Processing Record 45 of the Set 13 | kosa
# Processing Record 46 of the Set 13 | bichura
# Processing Record 47 of the Set 13 | galiwinku
# Processing Record 48 of the Set 13 | kachug
# Processing Record 49 of the Set 13 | peniche
# Processing Record 50 of the Set 13 | blagoyevo
# Processing Record 1 of the Set 14 | catuday
# Processing Record 2 of the Set 14 | camacha
# Processing Record 3 of the Set 14 | naco
# Processing Record 4 of the Set 14 | kazalinsk
# Processing Record 5 of the Set 14 | mount gambier
# Processing Record 6 of the Set 14 | san jeronimo
# Processing Record 7 of the Set 14 | kostino
# Processing Record 8 of the Set 14 | boquira
# Processing Record 9 of the Set 14 | polson
# Processing Record 10 of the Set 14 | miram shah
# Processing Record 11 of the Set 14 | zinapecuaro
# Processing Record 12 of the Set 14 | tres arroyos
# Processing Record 13 of the Set 14 | avera
# Processing Record 14 of the Set 14 | port hedland
# Processing Record 15 of the Set 14 | makinsk
# Processing Record 16 of the Set 14 | pacifica
# Processing Record 17 of the Set 14 | kavaratti
# Processing Record 18 of the Set 14 | acapulco
# Processing Record 19 of the Set 14 | port hueneme
# Processing Record 20 of the Set 14 | hihifo
# Processing Record 21 of the Set 14 | goderich
# Processing Record 22 of the Set 14 | zaraza
# Processing Record 23 of the Set 14 | emba
# Processing Record 24 of the Set 14 | portobelo
# Processing Record 25 of the Set 14 | jizan
# Processing Record 26 of the Set 14 | antalaha
# Processing Record 27 of the Set 14 | sedelnikovo
# Processing Record 28 of the Set 14 | utiroa
# City not found. Skipping...
# Processing Record 29 of the Set 14 | vestmannaeyjar
# Processing Record 30 of the Set 14 | dudinka
# Processing Record 31 of the Set 14 | petrolandia
# Processing Record 32 of the Set 14 | corn island
# Processing Record 33 of the Set 14 | waingapu
# Processing Record 34 of the Set 14 | muroto
# Processing Record 35 of the Set 14 | ferme-neuve
# Processing Record 36 of the Set 14 | punta alta
# Processing Record 37 of the Set 14 | ocos
# Processing Record 38 of the Set 14 | alcantara
# Processing Record 39 of the Set 14 | iracoubo
# Processing Record 40 of the Set 14 | katobu
# Processing Record 41 of the Set 14 | nyurba
# Processing Record 42 of the Set 14 | kamenka
# Processing Record 43 of the Set 14 | katherine
# Processing Record 44 of the Set 14 | cozumel
# Processing Record 45 of the Set 14 | aksay
# Processing Record 46 of the Set 14 | tunduru
# Processing Record 47 of the Set 14 | san andres
# Processing Record 48 of the Set 14 | dakar
# Processing Record 49 of the Set 14 | la ronge
# Processing Record 50 of the Set 14 | cervo
# Processing Record 1 of the Set 15 | la orilla
# Processing Record 2 of the Set 15 | puerto carreno
# Processing Record 3 of the Set 15 | moose factory
# Processing Record 4 of the Set 15 | kayerkan
# Processing Record 5 of the Set 15 | chalons-en-champagne
# Processing Record 6 of the Set 15 | one hundred mile house
# Processing Record 7 of the Set 15 | mecca
# Processing Record 8 of the Set 15 | glace bay
# Processing Record 9 of the Set 15 | churapcha
# Processing Record 10 of the Set 15 | mulege
# Processing Record 11 of the Set 15 | victor harbor
# Processing Record 12 of the Set 15 | darhan
# Processing Record 13 of the Set 15 | zyryanskoye
# Processing Record 14 of the Set 15 | paradwip
# Processing Record 15 of the Set 15 | shimoda
# Processing Record 16 of the Set 15 | ghanzi
# Processing Record 17 of the Set 15 | whitehorse
# Processing Record 18 of the Set 15 | blythe
# Processing Record 19 of the Set 15 | cehegin
# Processing Record 20 of the Set 15 | ksenyevka
# Processing Record 21 of the Set 15 | phan thiet
# Processing Record 22 of the Set 15 | chara
# Processing Record 23 of the Set 15 | chiuiesti
# Processing Record 24 of the Set 15 | hillsborough
# Processing Record 25 of the Set 15 | ikalamavony
# Processing Record 26 of the Set 15 | port augusta
# Processing Record 27 of the Set 15 | khonuu
# Processing Record 28 of the Set 15 | tarakan
# Processing Record 29 of the Set 15 | broken hill
# Processing Record 30 of the Set 15 | sheltozero
# Processing Record 31 of the Set 15 | koutiala
# Processing Record 32 of the Set 15 | cabo rojo
# Processing Record 33 of the Set 15 | mutsu
# Processing Record 34 of the Set 15 | nioro
# Processing Record 35 of the Set 15 | port keats
# Processing Record 36 of the Set 15 | mizpe ramon
# City not found. Skipping...
# Processing Record 37 of the Set 15 | tel aviv-yafo
# City not found. Skipping...
# Processing Record 38 of the Set 15 | pavlodar
# Processing Record 39 of the Set 15 | greiz
# Processing Record 40 of the Set 15 | iguguno
# Processing Record 41 of the Set 15 | mandalgovi
# Processing Record 42 of the Set 15 | nantucket
# Processing Record 43 of the Set 15 | bermeo
# Processing Record 44 of the Set 15 | aguimes
# Processing Record 45 of the Set 15 | tomakomai
# Processing Record 46 of the Set 15 | azimur
# City not found. Skipping...
# Processing Record 47 of the Set 15 | kem
# Processing Record 48 of the Set 15 | high rock
# Processing Record 49 of the Set 15 | araouane
# Processing Record 50 of the Set 15 | ulvik
# Processing Record 1 of the Set 16 | manado
# Processing Record 2 of the Set 16 | pimenta bueno
# Processing Record 3 of the Set 16 | baturaja
# Processing Record 4 of the Set 16 | scarborough
# Processing Record 5 of the Set 16 | navapur
# Processing Record 6 of the Set 16 | haimen
# Processing Record 7 of the Set 16 | teahupoo
# Processing Record 8 of the Set 16 | kjollefjord
# Processing Record 9 of the Set 16 | lakes entrance
# Processing Record 10 of the Set 16 | aksu
# Processing Record 11 of the Set 16 | prince george
# Processing Record 12 of the Set 16 | xining
# Processing Record 13 of the Set 16 | porto novo
# Processing Record 14 of the Set 16 | abu kamal
# Processing Record 15 of the Set 16 | bolungarvik
# Processing Record 16 of the Set 16 | kalaikunda
# Processing Record 17 of the Set 16 | inzer
# Processing Record 18 of the Set 16 | russell
# Processing Record 19 of the Set 16 | zachagansk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 733

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Qaanaaq      GL  77.48  -69.36     28.54        84          75
# 1   Kaitangata      NZ -46.28  169.85     45.00        72          90
# 2  Tuktoyaktuk      CA  69.45 -133.04     44.60        87          75
# 3        Melbu      NO  68.50   14.83     62.60        63           3
# 4        Kapaa      US  22.08 -159.32     78.80        74          20
#
#    Wind Speed Current Description
# 0        4.09       broken clouds
# 1        5.99     overcast clouds
# 2       13.87       broken clouds
# 3        9.17           clear sky
# 4       10.29          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")

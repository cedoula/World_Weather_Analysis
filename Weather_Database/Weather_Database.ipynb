# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 767

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | benghazi
# Processing Record 2 of the Set 1 | yellowknife
# Processing Record 3 of the Set 1 | kamina
# Processing Record 4 of the Set 1 | tramore
# Processing Record 5 of the Set 1 | nuuk
# Processing Record 6 of the Set 1 | hermanus
# Processing Record 7 of the Set 1 | victoria
# Processing Record 8 of the Set 1 | ushuaia
# Processing Record 9 of the Set 1 | palana
# Processing Record 10 of the Set 1 | saleaula
# City not found. Skipping...
# Processing Record 11 of the Set 1 | cockburn town
# Processing Record 12 of the Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 13 of the Set 1 | rikitea
# Processing Record 14 of the Set 1 | hobart
# Processing Record 15 of the Set 1 | hasaki
# Processing Record 16 of the Set 1 | otradnoye
# City not found. Skipping...
# Processing Record 17 of the Set 1 | mataura
# Processing Record 18 of the Set 1 | axim
# Processing Record 19 of the Set 1 | dikson
# Processing Record 20 of the Set 1 | arraial do cabo
# Processing Record 21 of the Set 1 | georgetown
# Processing Record 22 of the Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 23 of the Set 1 | kabwe
# Processing Record 24 of the Set 1 | albany
# Processing Record 25 of the Set 1 | yarada
# Processing Record 26 of the Set 1 | port elizabeth
# Processing Record 27 of the Set 1 | nanortalik
# Processing Record 28 of the Set 1 | siverek
# Processing Record 29 of the Set 1 | raisinghnagar
# Processing Record 30 of the Set 1 | bambous virieux
# Processing Record 31 of the Set 1 | chapais
# Processing Record 32 of the Set 1 | bani walid
# Processing Record 33 of the Set 1 | pisco
# Processing Record 34 of the Set 1 | fare
# Processing Record 35 of the Set 1 | bien hoa
# Processing Record 36 of the Set 1 | naftah
# City not found. Skipping...
# Processing Record 37 of the Set 1 | busselton
# Processing Record 38 of the Set 1 | maumere
# Processing Record 39 of the Set 1 | qaanaaq
# Processing Record 40 of the Set 1 | longyearbyen
# Processing Record 41 of the Set 1 | punta arenas
# Processing Record 42 of the Set 1 | calama
# Processing Record 43 of the Set 1 | alofi
# Processing Record 44 of the Set 1 | mahanoro
# City not found. Skipping...
# Processing Record 45 of the Set 1 | carbonia
# Processing Record 46 of the Set 1 | east london
# Processing Record 47 of the Set 1 | narsaq
# Processing Record 48 of the Set 1 | cape town
# Processing Record 49 of the Set 1 | ahipara
# Processing Record 50 of the Set 1 | butaritari
# Processing Record 1 of the Set 2 | hilo
# Processing Record 2 of the Set 2 | illoqqortoormiut
# Processing Record 3 of the Set 2 | cidreira
# Processing Record 4 of the Set 2 | luderitz
# Processing Record 5 of the Set 2 | vaini
# Processing Record 6 of the Set 2 | chokurdakh
# Processing Record 7 of the Set 2 | tasiilaq
# Processing Record 8 of the Set 2 | lisala
# Processing Record 9 of the Set 2 | adrar
# Processing Record 10 of the Set 2 | kapaa
# Processing Record 11 of the Set 2 | kroya
# Processing Record 12 of the Set 2 | bluff
# Processing Record 13 of the Set 2 | mar del plata
# Processing Record 14 of the Set 2 | brasileia
# Processing Record 15 of the Set 2 | nicoya
# Processing Record 16 of the Set 2 | port alfred
# Processing Record 17 of the Set 2 | airai
# Processing Record 18 of the Set 2 | los llanos de aridane
# Processing Record 19 of the Set 2 | northam
# Processing Record 20 of the Set 2 | celestun
# Processing Record 21 of the Set 2 | attawapiskat
# Processing Record 22 of the Set 2 | kununurra
# Processing Record 23 of the Set 2 | kodiak
# Processing Record 24 of the Set 2 | marsh harbour
# Processing Record 25 of the Set 2 | atar
# Processing Record 26 of the Set 2 | nikolskoye
# Processing Record 27 of the Set 2 | saint-augustin
# Processing Record 28 of the Set 2 | acajutla
# Processing Record 29 of the Set 2 | upernavik
# Processing Record 30 of the Set 2 | samarai
# Processing Record 31 of the Set 2 | karakendzha
# City not found. Skipping...
# Processing Record 32 of the Set 2 | isla mujeres
# Processing Record 33 of the Set 2 | tianpeng
# Processing Record 34 of the Set 2 | salalah
# Processing Record 35 of the Set 2 | faya
# Processing Record 36 of the Set 2 | hauzenberg
# Processing Record 37 of the Set 2 | porto santo
# Processing Record 38 of the Set 2 | cortez
# Processing Record 39 of the Set 2 | tharad
# Processing Record 40 of the Set 2 | thompson
# Processing Record 41 of the Set 2 | tiksi
# Processing Record 42 of the Set 2 | semey
# Processing Record 43 of the Set 2 | atuona
# Processing Record 44 of the Set 2 | kaeo
# Processing Record 45 of the Set 2 | sentyabrskiy
# Processing Record 46 of the Set 2 | pozzallo
# Processing Record 47 of the Set 2 | lebu
# Processing Record 48 of the Set 2 | lorengau
# Processing Record 49 of the Set 2 | sao joao da barra
# Processing Record 50 of the Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 1 of the Set 3 | saint george
# Processing Record 2 of the Set 3 | barrow
# Processing Record 3 of the Set 3 | bredasdorp
# Processing Record 4 of the Set 3 | wewak
# Processing Record 5 of the Set 3 | margate
# Processing Record 6 of the Set 3 | wufeng
# Processing Record 7 of the Set 3 | meadow lake
# Processing Record 8 of the Set 3 | souillac
# Processing Record 9 of the Set 3 | ibotirama
# Processing Record 10 of the Set 3 | vestmannaeyjar
# Processing Record 11 of the Set 3 | afogados da ingazeira
# Processing Record 12 of the Set 3 | fortuna
# Processing Record 13 of the Set 3 | lima
# Processing Record 14 of the Set 3 | codrington
# Processing Record 15 of the Set 3 | ribeira grande
# Processing Record 16 of the Set 3 | avarua
# Processing Record 17 of the Set 3 | necochea
# Processing Record 18 of the Set 3 | padang
# Processing Record 19 of the Set 3 | valjevo
# Processing Record 20 of the Set 3 | sorvag
# City not found. Skipping...
# Processing Record 21 of the Set 3 | jamestown
# Processing Record 22 of the Set 3 | broome
# Processing Record 23 of the Set 3 | barentsburg
# Processing Record 24 of the Set 3 | tawkar
# City not found. Skipping...
# Processing Record 25 of the Set 3 | waipawa
# Processing Record 26 of the Set 3 | aguie
# Processing Record 27 of the Set 3 | anadyr
# Processing Record 28 of the Set 3 | uusikaupunki
# Processing Record 29 of the Set 3 | arona
# Processing Record 30 of the Set 3 | ancud
# Processing Record 31 of the Set 3 | kanker
# Processing Record 32 of the Set 3 | hamilton
# Processing Record 33 of the Set 3 | knysna
# Processing Record 34 of the Set 3 | cherskiy
# Processing Record 35 of the Set 3 | moen
# Processing Record 36 of the Set 3 | praia
# Processing Record 37 of the Set 3 | paradwip
# Processing Record 38 of the Set 3 | new norfolk
# Processing Record 39 of the Set 3 | clyde river
# Processing Record 40 of the Set 3 | sioux lookout
# Processing Record 41 of the Set 3 | belen
# Processing Record 42 of the Set 3 | atambua
# Processing Record 43 of the Set 3 | hithadhoo
# Processing Record 44 of the Set 3 | puerto ayora
# Processing Record 45 of the Set 3 | khatanga
# Processing Record 46 of the Set 3 | banfora
# Processing Record 47 of the Set 3 | chuy
# Processing Record 48 of the Set 3 | carnarvon
# Processing Record 49 of the Set 3 | radnevo
# Processing Record 50 of the Set 3 | sao miguel do araguaia
# Processing Record 1 of the Set 4 | chardara
# Processing Record 2 of the Set 4 | norman wells
# Processing Record 3 of the Set 4 | kavaratti
# Processing Record 4 of the Set 4 | alexandria
# Processing Record 5 of the Set 4 | nouadhibou
# Processing Record 6 of the Set 4 | kachug
# Processing Record 7 of the Set 4 | atherton
# Processing Record 8 of the Set 4 | bethel
# Processing Record 9 of the Set 4 | namibe
# Processing Record 10 of the Set 4 | mahebourg
# Processing Record 11 of the Set 4 | saskylakh
# Processing Record 12 of the Set 4 | hengshui
# Processing Record 13 of the Set 4 | tigre
# Processing Record 14 of the Set 4 | tuatapere
# Processing Record 15 of the Set 4 | itaituba
# Processing Record 16 of the Set 4 | zhumadian
# Processing Record 17 of the Set 4 | saint-francois
# Processing Record 18 of the Set 4 | xining
# Processing Record 19 of the Set 4 | lasa
# Processing Record 20 of the Set 4 | san patricio
# Processing Record 21 of the Set 4 | marawi
# City not found. Skipping...
# Processing Record 22 of the Set 4 | samusu
# City not found. Skipping...
# Processing Record 23 of the Set 4 | port lincoln
# Processing Record 24 of the Set 4 | iqaluit
# Processing Record 25 of the Set 4 | gimli
# Processing Record 26 of the Set 4 | castro
# Processing Record 27 of the Set 4 | yar-sale
# Processing Record 28 of the Set 4 | cairo
# Processing Record 29 of the Set 4 | hervey bay
# Processing Record 30 of the Set 4 | fairview
# Processing Record 31 of the Set 4 | ilulissat
# Processing Record 32 of the Set 4 | bengkulu
# Processing Record 33 of the Set 4 | along
# Processing Record 34 of the Set 4 | peace river
# Processing Record 35 of the Set 4 | marcona
# Processing Record 36 of the Set 4 | oranjestad
# Processing Record 37 of the Set 4 | srednekolymsk
# Processing Record 38 of the Set 4 | shahrud
# Processing Record 39 of the Set 4 | geraldton
# Processing Record 40 of the Set 4 | blois
# Processing Record 41 of the Set 4 | elat
# Processing Record 42 of the Set 4 | kitimat
# Processing Record 43 of the Set 4 | spasskoye
# Processing Record 44 of the Set 4 | tautira
# Processing Record 45 of the Set 4 | darhan
# Processing Record 46 of the Set 4 | ayan
# Processing Record 47 of the Set 4 | jumla
# Processing Record 48 of the Set 4 | saint-philippe
# Processing Record 49 of the Set 4 | george
# Processing Record 50 of the Set 4 | puerto penasco
# Processing Record 1 of the Set 5 | opuwo
# Processing Record 2 of the Set 5 | lompoc
# Processing Record 3 of the Set 5 | mantua
# Processing Record 4 of the Set 5 | nizhneyansk
# Processing Record 5 of the Set 5 | ishigaki
# Processing Record 6 of the Set 5 | vyyezdnoye
# Processing Record 7 of the Set 5 | matara
# Processing Record 8 of the Set 5 | sayyan
# Processing Record 9 of the Set 5 | angra
# Processing Record 10 of the Set 5 | metehara
# City not found. Skipping...
# Processing Record 11 of the Set 5 | xiongzhou
# Processing Record 12 of the Set 5 | dingle
# Processing Record 13 of the Set 5 | bull savanna
# Processing Record 14 of the Set 5 | totma
# Processing Record 15 of the Set 5 | tumannyy
# Processing Record 16 of the Set 5 | ginir
# City not found. Skipping...
# Processing Record 17 of the Set 5 | petropavlovsk-kamchatskiy
# Processing Record 18 of the Set 5 | shimanovsk
# Processing Record 19 of the Set 5 | kostalexis
# Processing Record 20 of the Set 5 | hearst
# Processing Record 21 of the Set 5 | nola
# Processing Record 22 of the Set 5 | sjenica
# Processing Record 23 of the Set 5 | mackay
# Processing Record 24 of the Set 5 | biak
# Processing Record 25 of the Set 5 | leningradskiy
# Processing Record 26 of the Set 5 | port augusta
# Processing Record 27 of the Set 5 | katsuura
# Processing Record 28 of the Set 5 | eyrarbakki
# Processing Record 29 of the Set 5 | severo-kurilsk
# Processing Record 30 of the Set 5 | talnakh
# Processing Record 31 of the Set 5 | la ronge
# Processing Record 32 of the Set 5 | bushenyi
# Processing Record 33 of the Set 5 | kurchum
# Processing Record 34 of the Set 5 | inhambane
# Processing Record 35 of the Set 5 | sept-iles
# Processing Record 36 of the Set 5 | horki
# Processing Record 37 of the Set 5 | taltal
# Processing Record 38 of the Set 5 | char bhadrasan
# Processing Record 39 of the Set 5 | havoysund
# Processing Record 40 of the Set 5 | ballina
# Processing Record 41 of the Set 5 | burnie
# Processing Record 42 of the Set 5 | quatre cocos
# Processing Record 43 of the Set 5 | sao jose da coroa grande
# Processing Record 44 of the Set 5 | camacha
# Processing Record 45 of the Set 5 | santa cruz
# Processing Record 46 of the Set 5 | sisimiut
# Processing Record 47 of the Set 5 | teguise
# Processing Record 48 of the Set 5 | kaitangata
# Processing Record 49 of the Set 5 | port-cartier
# Processing Record 50 of the Set 5 | pevek
# Processing Record 1 of the Set 6 | stornoway
# Processing Record 2 of the Set 6 | puerto escondido
# Processing Record 3 of the Set 6 | labuhan
# Processing Record 4 of the Set 6 | freeport
# Processing Record 5 of the Set 6 | porto torres
# Processing Record 6 of the Set 6 | san luis
# Processing Record 7 of the Set 6 | sitka
# Processing Record 8 of the Set 6 | ponta do sol
# Processing Record 9 of the Set 6 | chichi
# Processing Record 10 of the Set 6 | harper
# Processing Record 11 of the Set 6 | bereda
# Processing Record 12 of the Set 6 | zarichne
# Processing Record 13 of the Set 6 | kamenka
# Processing Record 14 of the Set 6 | bargal
# Processing Record 15 of the Set 6 | amderma
# Processing Record 16 of the Set 6 | aksha
# Processing Record 17 of the Set 6 | maragogi
# Processing Record 18 of the Set 6 | lolua
# City not found. Skipping...
# Processing Record 19 of the Set 6 | comodoro rivadavia
# Processing Record 20 of the Set 6 | eten
# Processing Record 21 of the Set 6 | butembo
# Processing Record 22 of the Set 6 | meulaboh
# Processing Record 23 of the Set 6 | beringovskiy
# Processing Record 24 of the Set 6 | udachnyy
# Processing Record 25 of the Set 6 | san cristobal
# Processing Record 26 of the Set 6 | nkhata bay
# Processing Record 27 of the Set 6 | richards bay
# Processing Record 28 of the Set 6 | azimur
# City not found. Skipping...
# Processing Record 29 of the Set 6 | broken hill
# Processing Record 30 of the Set 6 | sabha
# Processing Record 31 of the Set 6 | butterworth
# Processing Record 32 of the Set 6 | chiguayante
# Processing Record 33 of the Set 6 | grand river south east
# Processing Record 34 of the Set 6 | dibulla
# Processing Record 35 of the Set 6 | naze
# Processing Record 36 of the Set 6 | havre-saint-pierre
# Processing Record 37 of the Set 6 | caravelas
# Processing Record 38 of the Set 6 | acapulco
# Processing Record 39 of the Set 6 | ojinaga
# Processing Record 40 of the Set 6 | mataram
# Processing Record 41 of the Set 6 | honningsvag
# Processing Record 42 of the Set 6 | provideniya
# Processing Record 43 of the Set 6 | bairiki
# Processing Record 44 of the Set 6 | kwinana
# Processing Record 45 of the Set 6 | neuquen
# Processing Record 46 of the Set 6 | grand centre
# Processing Record 47 of the Set 6 | sovetskiy
# Processing Record 48 of the Set 6 | cah ab
# City not found. Skipping...
# Processing Record 49 of the Set 6 | biabou
# Processing Record 50 of the Set 6 | vila franca do campo
# Processing Record 1 of the Set 7 | kahului
# Processing Record 2 of the Set 7 | bunda
# Processing Record 3 of the Set 7 | tazovskiy
# Processing Record 4 of the Set 7 | westpunt
# City not found. Skipping...
# Processing Record 5 of the Set 7 | karratha
# Processing Record 6 of the Set 7 | eruwa
# Processing Record 7 of the Set 7 | trat
# Processing Record 8 of the Set 7 | khandyga
# Processing Record 9 of the Set 7 | luohe
# Processing Record 10 of the Set 7 | hambantota
# Processing Record 11 of the Set 7 | mabaruma
# Processing Record 12 of the Set 7 | vokhma
# Processing Record 13 of the Set 7 | shu
# Processing Record 14 of the Set 7 | maltahohe
# Processing Record 15 of the Set 7 | avera
# Processing Record 16 of the Set 7 | tshela
# Processing Record 17 of the Set 7 | kadyy
# Processing Record 18 of the Set 7 | kivsharivka
# Processing Record 19 of the Set 7 | tukrah
# Processing Record 20 of the Set 7 | yirol
# City not found. Skipping...
# Processing Record 21 of the Set 7 | sal rei
# Processing Record 22 of the Set 7 | qarqin
# City not found. Skipping...
# Processing Record 23 of the Set 7 | kota kinabalu
# Processing Record 24 of the Set 7 | vallenar
# Processing Record 25 of the Set 7 | baruun-urt
# Processing Record 26 of the Set 7 | tual
# Processing Record 27 of the Set 7 | teya
# Processing Record 28 of the Set 7 | huarmey
# Processing Record 29 of the Set 7 | te anau
# Processing Record 30 of the Set 7 | port macquarie
# Processing Record 31 of the Set 7 | brae
# Processing Record 32 of the Set 7 | fairbanks
# Processing Record 33 of the Set 7 | lavrentiya
# Processing Record 34 of the Set 7 | akita
# Processing Record 35 of the Set 7 | jacareacanga
# Processing Record 36 of the Set 7 | nome
# Processing Record 37 of the Set 7 | berlevag
# Processing Record 38 of the Set 7 | guanica
# Processing Record 39 of the Set 7 | moissala
# Processing Record 40 of the Set 7 | desaguadero
# Processing Record 41 of the Set 7 | strezhevoy
# Processing Record 42 of the Set 7 | vao
# Processing Record 43 of the Set 7 | nuevitas
# Processing Record 44 of the Set 7 | cayenne
# Processing Record 45 of the Set 7 | tuktoyaktuk
# Processing Record 46 of the Set 7 | kutahya
# Processing Record 47 of the Set 7 | yuzhou
# Processing Record 48 of the Set 7 | kungurtug
# Processing Record 49 of the Set 7 | kieta
# Processing Record 50 of the Set 7 | qeshm
# Processing Record 1 of the Set 8 | mount gambier
# Processing Record 2 of the Set 8 | amuntai
# Processing Record 3 of the Set 8 | ostrovnoy
# Processing Record 4 of the Set 8 | altamont
# Processing Record 5 of the Set 8 | nabire
# Processing Record 6 of the Set 8 | trollhattan
# Processing Record 7 of the Set 8 | tacoronte
# Processing Record 8 of the Set 8 | ciechanow
# Processing Record 9 of the Set 8 | palabuhanratu
# Processing Record 10 of the Set 8 | mount pleasant
# Processing Record 11 of the Set 8 | sao filipe
# Processing Record 12 of the Set 8 | namatanai
# Processing Record 13 of the Set 8 | cascais
# Processing Record 14 of the Set 8 | nieuw nickerie
# Processing Record 15 of the Set 8 | hobyo
# Processing Record 16 of the Set 8 | rio gallegos
# Processing Record 17 of the Set 8 | pingliang
# Processing Record 18 of the Set 8 | atbasar
# Processing Record 19 of the Set 8 | aykhal
# Processing Record 20 of the Set 8 | ullapool
# Processing Record 21 of the Set 8 | ulladulla
# Processing Record 22 of the Set 8 | tambovka
# Processing Record 23 of the Set 8 | faanui
# Processing Record 24 of the Set 8 | granicesti
# Processing Record 25 of the Set 8 | sinkat
# City not found. Skipping...
# Processing Record 26 of the Set 8 | wilmington
# Processing Record 27 of the Set 8 | balkanabat
# Processing Record 28 of the Set 8 | ambilobe
# City not found. Skipping...
# Processing Record 29 of the Set 8 | aden
# Processing Record 30 of the Set 8 | roald
# Processing Record 31 of the Set 8 | nelson bay
# Processing Record 32 of the Set 8 | yavaros
# Processing Record 33 of the Set 8 | kaputa
# Processing Record 34 of the Set 8 | kaohsiung
# Processing Record 35 of the Set 8 | cabo san lucas
# Processing Record 36 of the Set 8 | mackenzie
# Processing Record 37 of the Set 8 | honiara
# Processing Record 38 of the Set 8 | kawalu
# Processing Record 39 of the Set 8 | batsfjord
# Processing Record 40 of the Set 8 | paredon
# Processing Record 41 of the Set 8 | nizhniy kuranakh
# Processing Record 42 of the Set 8 | edson
# Processing Record 43 of the Set 8 | uruzgan
# City not found. Skipping...
# Processing Record 44 of the Set 8 | rigaud
# Processing Record 45 of the Set 8 | sao domingos
# Processing Record 46 of the Set 8 | martapura
# Processing Record 47 of the Set 8 | jacarezinho
# Processing Record 48 of the Set 8 | veraval
# Processing Record 49 of the Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 50 of the Set 8 | utiroa
# Processing Record 1 of the Set 9 | solnechnyy
# Processing Record 2 of the Set 9 | winnemucca
# Processing Record 3 of the Set 9 | severodvinsk
# Processing Record 4 of the Set 9 | sorkjosen
# Processing Record 5 of the Set 9 | champerico
# Processing Record 6 of the Set 9 | seymchan
# Processing Record 7 of the Set 9 | himora
# City not found. Skipping...
# Processing Record 8 of the Set 9 | husavik
# Processing Record 9 of the Set 9 | oksfjord
# Processing Record 10 of the Set 9 | lloret de mar
# Processing Record 11 of the Set 9 | vila velha
# Processing Record 12 of the Set 9 | sydney mines
# Processing Record 13 of the Set 9 | salina cruz
# Processing Record 14 of the Set 9 | haapu
# Processing Record 15 of the Set 9 | tigil
# Processing Record 16 of the Set 9 | narasannapeta
# Processing Record 17 of the Set 9 | moosomin
# Processing Record 18 of the Set 9 | gillette
# Processing Record 19 of the Set 9 | zhicheng
# Processing Record 20 of the Set 9 | coquimbo
# Processing Record 21 of the Set 9 | kondoa
# Processing Record 22 of the Set 9 | tura
# Processing Record 23 of the Set 9 | noumea
# Processing Record 24 of the Set 9 | isangel
# Processing Record 25 of the Set 9 | el wasta
# Processing Record 26 of the Set 9 | fuengirola
# Processing Record 27 of the Set 9 | viedma
# Processing Record 28 of the Set 9 | podgornoye
# Processing Record 29 of the Set 9 | paucartambo
# Processing Record 30 of the Set 9 | port-gentil
# Processing Record 31 of the Set 9 | mazulskiy
# Processing Record 32 of the Set 9 | shar
# Processing Record 33 of the Set 9 | amlame
# Processing Record 34 of the Set 9 | vardo
# Processing Record 35 of the Set 9 | north bend
# Processing Record 36 of the Set 9 | leh
# Processing Record 37 of the Set 9 | georgiu-dezh
# Processing Record 38 of the Set 9 | tomatlan
# Processing Record 39 of the Set 9 | bay roberts
# Processing Record 40 of the Set 9 | olinda
# Processing Record 41 of the Set 9 | college
# Processing Record 42 of the Set 9 | kropotkin
# Processing Record 43 of the Set 9 | angoche
# Processing Record 44 of the Set 9 | grindavik
# Processing Record 45 of the Set 9 | yangambi
# Processing Record 46 of the Set 9 | gualaquiza
# Processing Record 47 of the Set 9 | mayo
# Processing Record 48 of the Set 9 | ningan
# Processing Record 49 of the Set 9 | mareeba
# Processing Record 50 of the Set 9 | hovd
# Processing Record 1 of the Set 10 | porto novo
# Processing Record 2 of the Set 10 | consett
# Processing Record 3 of the Set 10 | hami
# Processing Record 4 of the Set 10 | korla
# Processing Record 5 of the Set 10 | kongolo
# Processing Record 6 of the Set 10 | kedrovyy
# Processing Record 7 of the Set 10 | riachao das neves
# Processing Record 8 of the Set 10 | kolyvan
# Processing Record 9 of the Set 10 | yurgamysh
# Processing Record 10 of the Set 10 | manyana
# Processing Record 11 of the Set 10 | owo
# Processing Record 12 of the Set 10 | manzil salim
# City not found. Skipping...
# Processing Record 13 of the Set 10 | quelimane
# Processing Record 14 of the Set 10 | khani
# Processing Record 15 of the Set 10 | severobaykalsk
# Processing Record 16 of the Set 10 | santa luzia
# Processing Record 17 of the Set 10 | praia da vitoria
# Processing Record 18 of the Set 10 | armacao dos buzios
# Processing Record 19 of the Set 10 | singapore
# Processing Record 20 of the Set 10 | farafangana
# Processing Record 21 of the Set 10 | bollnas
# Processing Record 22 of the Set 10 | san policarpo
# Processing Record 23 of the Set 10 | miramar
# Processing Record 24 of the Set 10 | portland
# Processing Record 25 of the Set 10 | kota bahru
# Processing Record 26 of the Set 10 | skjervoy
# Processing Record 27 of the Set 10 | koumra
# Processing Record 28 of the Set 10 | pimenta bueno
# Processing Record 29 of the Set 10 | kaka
# Processing Record 30 of the Set 10 | kudahuvadhoo
# Processing Record 31 of the Set 10 | qinhuangdao
# Processing Record 32 of the Set 10 | georgetown
# Processing Record 33 of the Set 10 | ajaccio
# Processing Record 34 of the Set 10 | eyl
# Processing Record 35 of the Set 10 | vizal san pablo
# Processing Record 36 of the Set 10 | trairi
# Processing Record 37 of the Set 10 | zolotukhino
# Processing Record 38 of the Set 10 | vostok
# Processing Record 39 of the Set 10 | sakakah
# Processing Record 40 of the Set 10 | minsk
# Processing Record 41 of the Set 10 | jardim
# Processing Record 42 of the Set 10 | san rafael
# Processing Record 43 of the Set 10 | zaysan
# Processing Record 44 of the Set 10 | khash
# Processing Record 45 of the Set 10 | tucuman
# Processing Record 46 of the Set 10 | rawson
# Processing Record 47 of the Set 10 | modesto
# Processing Record 48 of the Set 10 | youghal
# Processing Record 49 of the Set 10 | carutapera
# Processing Record 50 of the Set 10 | kyzyl
# Processing Record 1 of the Set 11 | bahia blanca
# Processing Record 2 of the Set 11 | san quintin
# Processing Record 3 of the Set 11 | komsomolskiy
# Processing Record 4 of the Set 11 | naraina
# Processing Record 5 of the Set 11 | novikovo
# Processing Record 6 of the Set 11 | pelym
# Processing Record 7 of the Set 11 | ust-uda
# Processing Record 8 of the Set 11 | limbang
# Processing Record 9 of the Set 11 | wajima
# Processing Record 10 of the Set 11 | plouzane
# Processing Record 11 of the Set 11 | klaksvik
# City not found. Skipping...
# Processing Record 12 of the Set 11 | bilibino
# Processing Record 13 of the Set 11 | san juan
# Processing Record 14 of the Set 11 | lata
# Processing Record 15 of the Set 11 | terney
# Processing Record 16 of the Set 11 | aklavik
# Processing Record 17 of the Set 11 | ngunguru
# Processing Record 18 of the Set 11 | xingcheng
# Processing Record 19 of the Set 11 | kruisfontein
# Processing Record 20 of the Set 11 | polczyn-zdroj
# Processing Record 21 of the Set 11 | nuevo progreso
# Processing Record 22 of the Set 11 | vryheid
# Processing Record 23 of the Set 11 | crixas
# Processing Record 24 of the Set 11 | mehamn
# Processing Record 25 of the Set 11 | aykino
# Processing Record 26 of the Set 11 | kamenskoye
# Processing Record 27 of the Set 11 | kapit
# Processing Record 28 of the Set 11 | domoni
# Processing Record 29 of the Set 11 | turochak
# Processing Record 30 of the Set 11 | mys shmidta
# Processing Record 31 of the Set 11 | rucheng
# Processing Record 32 of the Set 11 | sibolga
# Processing Record 33 of the Set 11 | buala
# Processing Record 34 of the Set 11 | yarkovo
# Processing Record 35 of the Set 11 | dunedin
# Processing Record 36 of the Set 11 | bur gabo
# Processing Record 37 of the Set 11 | mongo
# Processing Record 38 of the Set 11 | alghero
# Processing Record 39 of the Set 11 | ilebo
# Processing Record 40 of the Set 11 | umea
# Processing Record 41 of the Set 11 | kouango
# Processing Record 42 of the Set 11 | beira
# Processing Record 43 of the Set 11 | nalut
# Processing Record 44 of the Set 11 | zhuanghe
# Processing Record 45 of the Set 11 | asyut
# Processing Record 46 of the Set 11 | khonuu
# Processing Record 47 of the Set 11 | taoudenni
# Processing Record 48 of the Set 11 | banda aceh
# Processing Record 49 of the Set 11 | ye
# City not found. Skipping...
# Processing Record 50 of the Set 11 | santa cruz do rio pardo
# Processing Record 1 of the Set 12 | asuncion
# Processing Record 2 of the Set 12 | mankera
# Processing Record 3 of the Set 12 | ambodifototra
# Processing Record 4 of the Set 12 | nishihara
# Processing Record 5 of the Set 12 | kiruna
# Processing Record 6 of the Set 12 | xadani
# Processing Record 7 of the Set 12 | maraba
# Processing Record 8 of the Set 12 | kharovsk
# Processing Record 9 of the Set 12 | hamilton
# Processing Record 10 of the Set 12 | sambava
# Processing Record 11 of the Set 12 | kabanjahe
# Processing Record 12 of the Set 12 | khromtau
# Processing Record 13 of the Set 12 | bandarbeyla
# Processing Record 14 of the Set 12 | louisbourg
# Processing Record 15 of the Set 12 | yabelo
# City not found. Skipping...
# Processing Record 16 of the Set 12 | ambon
# Processing Record 17 of the Set 12 | deniliquin
# Processing Record 18 of the Set 12 | zigong
# Processing Record 19 of the Set 12 | natal
# Processing Record 20 of the Set 12 | wad rawah
# City not found. Skipping...
# Processing Record 21 of the Set 12 | rio grande
# Processing Record 22 of the Set 12 | bambanglipuro
# Processing Record 23 of the Set 12 | chumikan
# Processing Record 24 of the Set 12 | carballo
# Processing Record 25 of the Set 12 | chabahar
# Processing Record 26 of the Set 12 | siderno
# Processing Record 27 of the Set 12 | yulara
# Processing Record 28 of the Set 12 | san jose
# Processing Record 29 of the Set 12 | kochkurovo
# Processing Record 30 of the Set 12 | moron
# Processing Record 31 of the Set 12 | hofu
# Processing Record 32 of the Set 12 | auki
# Processing Record 33 of the Set 12 | vygonichi
# Processing Record 34 of the Set 12 | alpena
# Processing Record 35 of the Set 12 | labytnangi
# Processing Record 36 of the Set 12 | kitakata
# Processing Record 37 of the Set 12 | coihaique
# Processing Record 38 of the Set 12 | antofagasta
# Processing Record 39 of the Set 12 | cay
# Processing Record 40 of the Set 12 | sadao
# Processing Record 41 of the Set 12 | tessalit
# Processing Record 42 of the Set 12 | geraldton
# Processing Record 43 of the Set 12 | alta floresta
# Processing Record 44 of the Set 12 | prince rupert
# Processing Record 45 of the Set 12 | high rock
# Processing Record 46 of the Set 12 | benguela
# Processing Record 47 of the Set 12 | raudeberg
# Processing Record 48 of the Set 12 | mandiana
# Processing Record 49 of the Set 12 | thomastown
# Processing Record 50 of the Set 12 | palmer
# Processing Record 1 of the Set 13 | olafsvik
# Processing Record 2 of the Set 13 | hofn
# Processing Record 3 of the Set 13 | vestmanna
# Processing Record 4 of the Set 13 | lagoa
# Processing Record 5 of the Set 13 | guerrero negro
# Processing Record 6 of the Set 13 | santa marta
# Processing Record 7 of the Set 13 | sorland
# Processing Record 8 of the Set 13 | joigny
# Processing Record 9 of the Set 13 | umzimvubu
# Processing Record 10 of the Set 13 | belaya gora
# Processing Record 11 of the Set 13 | hirtshals
# Processing Record 12 of the Set 13 | lazaro cardenas
# Processing Record 13 of the Set 13 | charters towers
# Processing Record 14 of the Set 13 | kutum
# Processing Record 15 of the Set 13 | itarema
# Processing Record 16 of the Set 13 | po
# Processing Record 17 of the Set 13 | sinazongwe
# Processing Record 18 of the Set 13 | sala
# Processing Record 19 of the Set 13 | supaul
# Processing Record 20 of the Set 13 | hohhot
# Processing Record 21 of the Set 13 | bogorodskoye
# Processing Record 22 of the Set 13 | emporia
# Processing Record 23 of the Set 13 | nantucket
# Processing Record 24 of the Set 13 | mulege
# Processing Record 25 of the Set 13 | saldanha
# Processing Record 26 of the Set 13 | juegang
# Processing Record 27 of the Set 13 | willowmore
# Processing Record 28 of the Set 13 | algete
# Processing Record 29 of the Set 13 | avanigadda
# Processing Record 30 of the Set 13 | albacete
# Processing Record 31 of the Set 13 | galesong
# Processing Record 32 of the Set 13 | shache
# Processing Record 33 of the Set 13 | gaspe
# Processing Record 34 of the Set 13 | talara
# Processing Record 35 of the Set 13 | shagonar
# Processing Record 36 of the Set 13 | port hedland
# Processing Record 37 of the Set 13 | eirunepe
# Processing Record 38 of the Set 13 | maridi
# Processing Record 39 of the Set 13 | farah
# City not found. Skipping...
# Processing Record 40 of the Set 13 | rungata
# Processing Record 41 of the Set 13 | iwamizawa
# Processing Record 42 of the Set 13 | hargeysa
# Processing Record 43 of the Set 13 | cabatuan
# Processing Record 44 of the Set 13 | japura
# Processing Record 45 of the Set 13 | qaqortoq
# Processing Record 46 of the Set 13 | kemijarvi
# Processing Record 47 of the Set 13 | vattalkundu
# Processing Record 48 of the Set 13 | kismayo
# Processing Record 49 of the Set 13 | yenagoa
# Processing Record 50 of the Set 13 | savonlinna
# Processing Record 1 of the Set 14 | grand-santi
# Processing Record 2 of the Set 14 | qinzhou
# Processing Record 3 of the Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 4 of the Set 14 | play cu
# Processing Record 5 of the Set 14 | yoichi
# Processing Record 6 of the Set 14 | muros
# Processing Record 7 of the Set 14 | dublin
# Processing Record 8 of the Set 14 | warri
# Processing Record 9 of the Set 14 | jalu
# Processing Record 10 of the Set 14 | oxapampa
# Processing Record 11 of the Set 14 | saint-pierre
# Processing Record 12 of the Set 14 | spearfish
# Processing Record 13 of the Set 14 | umm lajj
# Processing Record 14 of the Set 14 | katobu
# Processing Record 15 of the Set 14 | mocuba
# Processing Record 16 of the Set 14 | kilindoni
# Processing Record 17 of the Set 14 | nakambala
# Processing Record 18 of the Set 14 | nkan
# Processing Record 19 of the Set 14 | say
# Processing Record 20 of the Set 14 | westport
# Processing Record 21 of the Set 14 | rosario
# Processing Record 22 of the Set 14 | maryville
# Processing Record 23 of the Set 14 | dali
# Processing Record 24 of the Set 14 | mahajanga
# Processing Record 25 of the Set 14 | urumqi
# Processing Record 26 of the Set 14 | hailey
# Processing Record 27 of the Set 14 | atagay
# Processing Record 28 of the Set 14 | tokur
# Processing Record 29 of the Set 14 | deputatskiy
# Processing Record 30 of the Set 14 | puerto narino
# Processing Record 31 of the Set 14 | esperance
# Processing Record 32 of the Set 14 | mullaitivu
# Processing Record 33 of the Set 14 | saint-joseph
# Processing Record 34 of the Set 14 | kadykchan
# Processing Record 35 of the Set 14 | hagi
# Processing Record 36 of the Set 14 | brigantine
# Processing Record 37 of the Set 14 | cockburn town
# Processing Record 38 of the Set 14 | ust-karsk
# Processing Record 39 of the Set 14 | tetiz
# Processing Record 40 of the Set 14 | minot
# Processing Record 41 of the Set 14 | syracuse
# Processing Record 42 of the Set 14 | medicina
# Processing Record 43 of the Set 14 | semirom
# Processing Record 44 of the Set 14 | sao miguel do tapuio
# Processing Record 45 of the Set 14 | sorong
# Processing Record 46 of the Set 14 | minab
# Processing Record 47 of the Set 14 | okhotsk
# Processing Record 48 of the Set 14 | moranbah
# Processing Record 49 of the Set 14 | petatlan
# Processing Record 50 of the Set 14 | brenham
# Processing Record 1 of the Set 15 | tutoia
# Processing Record 2 of the Set 15 | pangkalanbuun
# Processing Record 3 of the Set 15 | quarai
# Processing Record 4 of the Set 15 | shakawe
# Processing Record 5 of the Set 15 | kendari
# Processing Record 6 of the Set 15 | mandan
# Processing Record 7 of the Set 15 | port hardy
# Processing Record 8 of the Set 15 | bathsheba
# Processing Record 9 of the Set 15 | korcula
# Processing Record 10 of the Set 15 | jerome
# Processing Record 11 of the Set 15 | aksarka
# Processing Record 12 of the Set 15 | mandalgovi
# Processing Record 13 of the Set 15 | kushiro
# Processing Record 14 of the Set 15 | touros
# Processing Record 15 of the Set 15 | poya
# Processing Record 16 of the Set 15 | sveio
# Processing Record 17 of the Set 15 | coari
# Processing Record 18 of the Set 15 | guarapari
# Processing Record 19 of the Set 15 | bilma
# Processing Record 20 of the Set 15 | scottsbluff
# Processing Record 21 of the Set 15 | akonolinga
# Processing Record 22 of the Set 15 | yaan
# Processing Record 23 of the Set 15 | menongue
# Processing Record 24 of the Set 15 | krasnoselkup
# Processing Record 25 of the Set 15 | sabzevar
# Processing Record 26 of the Set 15 | bonham
# Processing Record 27 of the Set 15 | lamas
# Processing Record 28 of the Set 15 | bubaque
# Processing Record 29 of the Set 15 | asau
# City not found. Skipping...
# Processing Record 30 of the Set 15 | zharkent
# Processing Record 31 of the Set 15 | tucupita
# Processing Record 32 of the Set 15 | oxbow
# Processing Record 33 of the Set 15 | roros
# Processing Record 34 of the Set 15 | san lorenzo
# Processing Record 35 of the Set 15 | petropavl
# Processing Record 36 of the Set 15 | luchegorsk
# Processing Record 37 of the Set 15 | pemba
# Processing Record 38 of the Set 15 | yichang
# Processing Record 39 of the Set 15 | ler
# Processing Record 40 of the Set 15 | marv dasht
# Processing Record 41 of the Set 15 | cervo
# Processing Record 42 of the Set 15 | yumen
# Processing Record 43 of the Set 15 | lumphat
# Processing Record 44 of the Set 15 | saint anthony
# Processing Record 45 of the Set 15 | pavlodar

# %%
# Check numer of cities
len(city_data)
# Out:
# 733

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Qaanaaq      GL  77.48  -69.36     28.54        84          75
# 1   Kaitangata      NZ -46.28  169.85     45.00        72          90
# 2  Tuktoyaktuk      CA  69.45 -133.04     44.60        87          75
# 3        Melbu      NO  68.50   14.83     62.60        63           3
# 4        Kapaa      US  22.08 -159.32     78.80        74          20
#
#    Wind Speed Current Description
# 0        4.09       broken clouds
# 1        5.99     overcast clouds
# 2       13.87       broken clouds
# 3        9.17           clear sky
# 4       10.29          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
